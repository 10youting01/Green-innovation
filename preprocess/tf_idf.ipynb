# %%
import os
import re
import pandas as pd
import numpy as np

# %% [markdown]
# ## Preprocess

# %%
import re
import string
import spacy
from nltk.corpus import stopwords

# %%
# 載入 spaCy 英文模型
nlp = spacy.load("en_core_web_sm", disable=["ner", "parser"])  # 只保留 tok/pos/lemma

# 載入停用詞表
stop_words = set(stopwords.words('english'))

# %%
def preprocess(text):
    # 1. Lowercasing
    text = text.lower()

    # 2. Removing Punctuation & Special Characters
    punctuation_pattern = r'[^\w\s]'
    text = re.sub(punctuation_pattern, '', text)

    # 3. Removing Stop-Words Removal
    word_tokens = text.split()
    text = [word for word in word_tokens if word not in stop_words]

    # 4. Removal of URLs
    url_pattern = r'http\S+|www\S+|https\S+'
    text = re.sub(url_pattern, '', ' '.join(text))

    # 5. 移除所有數字（包含詞中、連結、日期等）
    text = re.sub(r"\b\d+\b", " ", text)

    # 6. 移除所有標點符號
    text = text.translate(str.maketrans("", "", string.punctuation))

    # 7. 多餘空白壓縮為單一空白
    text = re.sub(r"\s+", " ", text)

    # 8. Tokenization + Lemmatization
    doc = nlp(text)
    tokens = [
        token.lemma_ for token in doc
    ]

    return " ".join(tokens)

# %% [markdown]
# ## Load file

# %%
# read txt from CSR_report_processed_v4_gemini_v0
# Path to the folder containing the txt files
folder_path = "../CSR_report_processed_v4_gemini_v0"
xy_cpc = pd.read_csv("../output_dataset/csr_y_cpc.csv")
filled_flag = pd.read_csv("../output_dataset/csr_embeddings_leq2019_flag.csv")

# Filter filled_flag for is_imputed == False
valid_flags = filled_flag[filled_flag["is_imputed"] == False]

# Get the set of valid filenames
valid_filenames = set(valid_flags["file_name"]) & set(xy_cpc["file_name"])

# %%
# List to storprocessed = []
processed = []

for filename in list(valid_filenames):
    file_path = os.path.join(folder_path, filename + "_v0_gemini_corrected.txt")
    if os.path.exists(file_path):
        with open(file_path, "r", encoding="utf-8") as f:
            raw = f.read()
            clean = preprocess(raw)
            row = xy_cpc[xy_cpc["file_name"] == filename].iloc[0]
            processed.append({
                "filename": filename,
                "ticker": row["ticker"],
                "year": row["year"],
                "clean_text": clean,
                "patent_count": row["patents_count"],
                "citation_count": row["total_5yr_forward_citations"]
            })
        print(f"Processed {filename} with {len(processed[-1]['clean_text'].split())} tokens.")
    else:
        print(f"File {file_path} does not exist.")

# 儲存為 CSV
df_processed = pd.DataFrame(processed)
df_processed.to_csv("../output_dataset/csr_text_processed_v0_preprocessed.csv", index=False)
print(f"Saved {len(df_processed)} processed documents.")
# Out:
# Processed NYSE_SCS_2019 with 10429 tokens.
# Processed NYSE_INGR_2016 with 3776 tokens.
# Processed NYSE_CMI_2019 with 15105 tokens.
# Processed NASDAQ_INTC_2007 with 36429 tokens.
# Processed NYSE_PRU_2018 with 12877 tokens.
# Processed NYSE_WMT_2013 with 33058 tokens.
# Processed NYSE_WLK_2017 with 2581 tokens.
# Processed NYSE_VZ_2005 with 11134 tokens.
# Processed NYSE_TSN_2009 with 28320 tokens.
# Processed NYSE_APD_2019 with 24618 tokens.
# Processed NYSE_APA_2015 with 4325 tokens.
# Processed NYSE_ALB_2009 with 2668 tokens.
# Processed NYSE_NEM_2019 with 58972 tokens.
# Processed NASDAQ_IOSP_2018 with 10023 tokens.
# Processed NYSE_DTE_2015 with 884 tokens.
# Processed NYSE_WFC_2015 with 16397 tokens.
# Processed NASDAQ_MSFT_2007 with 1378 tokens.
# Processed NYSE_CF_2012 with 3099 tokens.
# Processed NYSE_ICE_2016 with 5881 tokens.
# Processed NASDAQ_AAPL_2016 with 11171 tokens.
# Processed NYSE_ORCL_2010 with 10824 tokens.
# Processed NYSE_AXP_2019 with 17684 tokens.
# Processed NYSE_SLB_2017 with 20560 tokens.
# Processed NYSE_TEL_2019 with 10156 tokens.
# Processed NYSE_IP_2017 with 5181 tokens.
# Processed NASDAQ_SBUX_2019 with 3023 tokens.
# Processed NYSE_WM_2013 with 16400 tokens.
# Processed NYSE_SMG_2014 with 21238 tokens.
# Processed NASDAQ_SEDG_2018 with 6313 tokens.
# Processed NYSE_DOW_2016 with 24115 tokens.
# Processed NYSE_T_2015 with 2618 tokens.
# Processed NYSE_MRK_2019 with 24472 tokens.
# Processed NYSE_RSG_2015 with 5457 tokens.
# Processed NYSE_ABT_2016 with 25087 tokens.
# Processed NYSE_T_2007 with 7753 tokens.
# Processed NYSE_AXP_2017 with 16022 tokens.
# Processed NYSE_BBY_2014 with 5478 tokens.
# Processed NYSE_FMC_2015 with 9652 tokens.
# Processed NYSE_AXP_2016 with 16345 tokens.
# Processed NYSE_TSN_2017 with 14219 tokens.
# Processed NASDAQ_EBAY_2016 with 2467 tokens.
# Processed NYSE_BLL_2007 with 9298 tokens.
# Processed NYSE_WMT_2006 with 9532 tokens.
# Processed NYSE_X_2017 with 6038 tokens.
# Processed NYSE_FDX_2015 with 10008 tokens.
# Processed NYSE_TNC_2012 with 2978 tokens.
# Processed NYSE_WMT_2011 with 24625 tokens.
# Processed NASDAQ_GRMN_2016 with 2932 tokens.
# Processed NYSE_CPS_2019 with 14245 tokens.
# Processed NYSE_ES_2019 with 21971 tokens.
# Processed NYSE_XOM_2016 with 17210 tokens.
# Processed NASDAQ_CDNS_2019 with 5326 tokens.
# Processed NYSE_DCI_2017 with 3657 tokens.
# Processed NASDAQ_INTU_2019 with 7385 tokens.
# Processed NASDAQ_INFN_2018 with 8433 tokens.
# Processed NASDAQ_TXN_2017 with 4150 tokens.
# Processed NYSE_GS_2007 with 5314 tokens.
# Processed NYSE_OC_2014 with 977 tokens.
# Processed NYSE_SWK_2015 with 1418 tokens.
# Processed NASDAQ_AAPL_2019 with 23535 tokens.
# Processed NYSE_DTE_2018 with 3542 tokens.
# Processed NASDAQ_MSFT_2004 with 19724 tokens.
# Processed NYSE_WRI_2015 with 8212 tokens.
# Processed NYSE_CNX_2013 with 12797 tokens.
# Processed NYSE_ECL_2017 with 5689 tokens.
# Processed NYSE_ABBV_2019 with 9535 tokens.
# Processed NYSE_IQV_2014 with 6075 tokens.
# Processed NYSE_CF_2013 with 3355 tokens.
# Processed NASDAQ_GNTX_2018 with 3698 tokens.
# Processed NYSE_MS_2014 with 21382 tokens.
# Processed NYSE_AIG_2018 with 5593 tokens.
# Processed NYSE_DUK_2014 with 9843 tokens.
# Processed NYSE_PK_2019 with 6721 tokens.
# Processed NASDAQ_ILMN_2019 with 12971 tokens.
# Processed NYSE_OMC_2018 with 8227 tokens.
# Processed NYSE_DUK_2012 with 11959 tokens.
# Processed NYSE_XRX_2017 with 1485 tokens.
# Processed NASDAQ_ICFI_2019 with 8402 tokens.
# Processed NASDAQ_SEDG_2019 with 7074 tokens.
# Processed NYSE_FLS_2018 with 4949 tokens.
# Processed NASDAQ_SBUX_2003 with 12163 tokens.
# Processed NYSE_BDX_2014 with 3333 tokens.
# Processed NYSE_RHI_2019 with 7629 tokens.
# Processed NYSE_XOM_2018 with 10199 tokens.
# Processed NYSE_ES_2014 with 23587 tokens.
# Processed NYSE_PBI_2012 with 8336 tokens.
# Processed NYSE_NSC_2015 with 25468 tokens.
# Processed NYSE_NSC_2014 with 25958 tokens.
# Processed NASDAQ_DIOD_2019 with 19631 tokens.
# Processed NASDAQ_ADBE_2013 with 1259 tokens.
# Processed NYSE_ACCO_2017 with 5841 tokens.
# Processed NYSE_RSG_2019 with 8311 tokens.
# Processed NYSE_GS_2018 with 10306 tokens.
# Processed NYSE_A_2005 with 8632 tokens.
# Processed NASDAQ_ADI_2019 with 9772 tokens.
# Processed NASDAQ_NXPI_2019 with 20839 tokens.
# Processed NYSE_SO_2018 with 6913 tokens.
# Processed NYSE_COP_2016 with 13681 tokens.
# Processed NYSE_DOW_2019 with 15238 tokens.
# Processed NYSE_ORCL_2014 with 18369 tokens.
# Processed NYSE_CVX_2014 with 6445 tokens.
# Processed NASDAQ_ADBE_2019 with 3060 tokens.
# Processed NYSE_RIG_2019 with 8850 tokens.
# Processed NYSE_LII_2015 with 1911 tokens.
# Processed NYSE_PG_2009 with 21033 tokens.
# Processed NYSE_T_2014 with 859 tokens.
# Processed NYSE_XOM_2017 with 7270 tokens.
# Processed NASDAQ_ADBE_2015 with 1648 tokens.
# Processed NYSE_SXT_2018 with 5771 tokens.
# Processed NASDAQ_INTC_2015 with 28219 tokens.
# Processed NYSE_MS_2019 with 11550 tokens.
# Processed NYSE_ORCL_2008 with 5020 tokens.
# Processed NASDAQ_AMGN_2014 with 4695 tokens.
# Processed NYSE_TXT_2019 with 7411 tokens.
# Processed NASDAQ_STX_2015 with 9823 tokens.
# Processed NYSE_CAT_2017 with 3306 tokens.
# Processed NYSE_WM_2010 with 1151 tokens.
# Processed NYSE_AIG_2016 with 1772 tokens.
# Processed NYSE_CNX_2011 with 11303 tokens.
# Processed NYSE_DCI_2015 with 2374 tokens.
# Processed NYSE_CNX_2015 with 12646 tokens.
# Processed NYSE_TMO_2019 with 12445 tokens.
# Processed NYSE_ECL_2009 with 7202 tokens.
# Processed NYSE_PH_2018 with 3533 tokens.
# Processed NYSE_SHW_2019 with 9052 tokens.
# Processed NASDAQ_WDC_2019 with 11833 tokens.
# Processed NYSE_AES_2017 with 4744 tokens.
# Processed NASDAQ_NXPI_2017 with 20156 tokens.
# Processed NYSE_GM_2016 with 33876 tokens.
# Processed NASDAQ_IOSP_2008 with 2157 tokens.
# Processed NYSE_NKE_2011 with 26648 tokens.
# Processed NYSE_MAN_2017 with 1546 tokens.
# Processed NYSE_ES_2018 with 21723 tokens.
# Processed NYSE_APO_2018 with 2469 tokens.
# Processed NASDAQ_COMM_2019 with 22785 tokens.
# Processed NYSE_APD_2018 with 22164 tokens.
# Processed NYSE_UNM_2019 with 8235 tokens.
# Processed NYSE_BDX_2017 with 9577 tokens.
# Processed NYSE_ACCO_2019 with 1791 tokens.
# Processed NYSE_CVX_2018 with 8463 tokens.
# Processed NASDAQ_BIIB_2016 with 17125 tokens.
# Processed NYSE_PG_2012 with 19654 tokens.
# Processed NYSE_F_2016 with 46780 tokens.
# Processed NASDAQ_ADBE_2018 with 2141 tokens.
# Processed NYSE_MPC_2019 with 19410 tokens.
# Processed NYSE_MOD_2019 with 6629 tokens.
# Processed NYSE_XOM_2013 with 22286 tokens.
# Processed NYSE_ATR_2014 with 3668 tokens.
# Processed NYSE_GPC_2017 with 3123 tokens.
# Processed NYSE_PRU_2015 with 7463 tokens.
# Processed NASDAQ_MSFT_2017 with 7336 tokens.
# Processed NASDAQ_UNFI_2014 with 3118 tokens.
# Processed NYSE_CMI_2004 with 9987 tokens.
# Processed NYSE_ABBV_2018 with 18600 tokens.
# Processed NASDAQ_THRM_2019 with 6178 tokens.
# Processed NYSE_DD_2017 with 17975 tokens.
# Processed NASDAQ_MCHP_2018 with 6540 tokens.
# Processed NYSE_PSX_2017 with 8181 tokens.
# Processed NYSE_NSC_2011 with 14335 tokens.
# Processed NYSE_NOC_2014 with 13796 tokens.
# Processed NYSE_VAR_2018 with 4060 tokens.
# Processed NYSE_UTX_2018 with 8452 tokens.
# Processed NYSE_DTE_2017 with 3037 tokens.
# Processed NYSE_APO_2019 with 17633 tokens.
# Processed NYSE_CAT_2018 with 3525 tokens.
# Processed NYSE_KMB_2014 with 9081 tokens.
# Processed NYSE_T_2019 with 7640 tokens.
# Processed NASDAQ_TXN_2018 with 2330 tokens.
# Processed NASDAQ_NTGR_2016 with 495 tokens.
# Processed NYSE_ESE_2018 with 2483 tokens.
# Processed NYSE_CVX_2003 with 6239 tokens.
# Processed NASDAQ_IOSP_2013 with 6767 tokens.
# Processed NYSE_CBT_2011 with 2800 tokens.
# Processed NYSE_CMI_2007 with 17986 tokens.
# Processed NYSE_TBI_2018 with 4988 tokens.
# Processed NYSE_CMI_2008 with 21508 tokens.
# Processed NYSE_GIS_2018 with 19151 tokens.
# Processed NYSE_JLL_2015 with 10401 tokens.
# Processed NYSE_OMC_2016 with 7173 tokens.
# Processed NYSE_TSE_2019 with 13722 tokens.
# Processed NYSE_TDC_2018 with 13259 tokens.
# Processed NYSE_A_2012 with 12502 tokens.
# Processed NYSE_SCS_2016 with 5440 tokens.
# Processed NYSE_KMB_2018 with 13083 tokens.
# Processed NYSE_MMC_2012 with 6349 tokens.
# Processed NASDAQ_ALXN_2019 with 11144 tokens.
# Processed NYSE_JNJ_2013 with 40381 tokens.
# Processed NYSE_TT_2011 with 14619 tokens.
# Processed NYSE_DGX_2019 with 9293 tokens.
# Processed NYSE_GTES_2018 with 1691 tokens.
# Processed NYSE_GPK_2019 with 15523 tokens.
# Processed NASDAQ_SBUX_2008 with 15038 tokens.
# Processed NYSE_OC_2008 with 2783 tokens.
# Processed NYSE_CAH_2016 with 1799 tokens.
# Processed NASDAQ_RUN_2019 with 7420 tokens.
# Processed NYSE_BBY_2018 with 10914 tokens.
# Processed NYSE_NKE_2006 with 34998 tokens.
# Processed NYSE_OSK_2018 with 9388 tokens.
# Processed NYSE_BAX_2011 with 52348 tokens.
# Processed NASDAQ_COMM_2016 with 3536 tokens.
# Processed NYSE_CL_2015 with 25444 tokens.
# Processed NASDAQ_SHOO_2019 with 8937 tokens.
# Processed NYSE_MS_2012 with 20036 tokens.
# Processed NASDAQ_SBUX_2014 with 3763 tokens.
# Processed NASDAQ_IOSP_2011 with 5652 tokens.
# Processed NYSE_OSK_2013 with 6747 tokens.
# Processed NYSE_UNM_2016 with 2735 tokens.
# Processed NYSE_BHC_2019 with 7316 tokens.
# Processed NYSE_RMD_2017 with 8509 tokens.
# Processed NYSE_BBY_2017 with 9591 tokens.
# Processed NASDAQ_INTC_2016 with 26337 tokens.
# Processed NYSE_OSK_2017 with 9938 tokens.
# Processed NYSE_PVH_2019 with 13607 tokens.
# Processed NYSE_AQUA_2015 with 1776 tokens.
# Processed NYSE_HPE_2016 with 18156 tokens.
# Processed NYSE_ALB_2017 with 12713 tokens.
# Processed NYSE_JNJ_2015 with 33721 tokens.
# Processed NYSE_FDX_2017 with 15005 tokens.
# Processed NYSE_NWL_2019 with 7897 tokens.
# Processed NASDAQ_CSCO_2007 with 20654 tokens.
# Processed NYSE_PSX_2019 with 11423 tokens.
# Processed NYSE_SLB_2019 with 23947 tokens.
# Processed NASDAQ_NTAP_2019 with 5647 tokens.
# Processed NASDAQ_STX_2017 with 13532 tokens.
# Processed NASDAQ_ERII_2019 with 6382 tokens.
# Processed NYSE_ECL_2006 with 5174 tokens.
# Processed NYSE_VZ_2007 with 8675 tokens.
# Processed NYSE_IBM_2002 with 16058 tokens.
# Processed NYSE_AON_2019 with 6627 tokens.
# Processed NYSE_LLY_2011 with 11348 tokens.
# Processed NASDAQ_NVDA_2019 with 14919 tokens.
# Processed NYSE_JLL_2016 with 14442 tokens.
# Processed NASDAQ_FITB_2015 with 5431 tokens.
# Processed NASDAQ_TXN_2011 with 3806 tokens.
# Processed NYSE_CBT_2013 with 4736 tokens.
# Processed NASDAQ_MDLZ_2017 with 9384 tokens.
# Processed NASDAQ_CSCO_2005 with 16365 tokens.
# Processed NYSE_BMY_2016 with 7478 tokens.
# Processed NASDAQ_INTC_2012 with 46296 tokens.
# Processed NASDAQ_ON_2016 with 14663 tokens.
# Processed NYSE_PRU_2017 with 10489 tokens.
# Processed NYSE_SO_2016 with 3221 tokens.
# Processed NYSE_VZ_2016 with 6132 tokens.
# Processed NASDAQ_MSFT_2011 with 12886 tokens.
# Processed NYSE_FDX_2019 with 21138 tokens.
# Processed NYSE_GIS_2013 with 22008 tokens.
# Processed NASDAQ_INTC_2006 with 24536 tokens.
# Processed NYSE_GPK_2018 with 2264 tokens.
# Processed NASDAQ_SONO_2018 with 1866 tokens.
# Processed NASDAQ_MCHP_2019 with 6904 tokens.
# Processed NYSE_RMD_2012 with 23806 tokens.
# Processed NYSE_ABT_2014 with 23917 tokens.
# Processed NYSE_DHR_2016 with 3176 tokens.
# Processed NYSE_BKD_2016 with 5386 tokens.
# Processed NASDAQ_IOSP_2007 with 1317 tokens.
# Processed NYSE_APTV_2018 with 123 tokens.
# Processed NASDAQ_ITRI_2018 with 2746 tokens.
# Processed NYSE_KBR_2019 with 18417 tokens.
# Processed NYSE_MDT_2018 with 11224 tokens.
# Processed NYSE_JLL_2010 with 17906 tokens.
# Processed NYSE_ESE_2017 with 5578 tokens.
# Processed NYSE_DGX_2018 with 12485 tokens.
# Processed NYSE_NOC_2017 with 13292 tokens.
# Processed NYSE_H_2011 with 6683 tokens.
# Processed NYSE_DUK_2016 with 11749 tokens.
# Processed NYSE_SWK_2017 with 1759 tokens.
# Processed NYSE_WMT_2019 with 17370 tokens.
# Processed NYSE_TNC_2016 with 7511 tokens.
# Processed NYSE_DTE_2013 with 10346 tokens.
# Processed NYSE_CL_2016 with 24727 tokens.
# Processed NYSE_PHM_2015 with 2585 tokens.
# Processed NYSE_MSI_2017 with 3974 tokens.
# Processed NASDAQ_IOSP_2016 with 6204 tokens.
# Processed NYSE_PG_2015 with 19092 tokens.
# Processed NYSE_SHW_2018 with 7171 tokens.
# Processed NYSE_GIS_2012 with 15981 tokens.
# Processed NYSE_KMB_2016 with 11168 tokens.
# Processed NYSE_CB_2019 with 4680 tokens.
# Processed NYSE_MMC_2011 with 2433 tokens.
# Processed NYSE_PVH_2018 with 12258 tokens.
# Processed NYSE_PFE_2009 with 16525 tokens.
# Processed NYSE_TNC_2018 with 10568 tokens.
# Processed NYSE_HY_2019 with 3645 tokens.
# Processed NASDAQ_CSCO_2011 with 38058 tokens.
# Processed NYSE_WRI_2013 with 7863 tokens.
# Processed NYSE_JBL_2015 with 15248 tokens.
# Processed NYSE_MRK_2018 with 15581 tokens.
# Processed NYSE_ORA_2017 with 4942 tokens.
# Processed NYSE_BMY_2010 with 3418 tokens.
# Processed NASDAQ_NVDA_2016 with 13178 tokens.
# Processed NYSE_LEA_2013 with 2631 tokens.
# Processed NYSE_NBL_2018 with 12579 tokens.
# Processed NASDAQ_IOSP_2017 with 9991 tokens.
# Processed NYSE_WFC_2014 with 2433 tokens.
# Processed NASDAQ_REGN_2018 with 12048 tokens.
# Processed NYSE_BBY_2013 with 7089 tokens.
# Processed NYSE_WMT_2007 with 20247 tokens.
# Processed NASDAQ_AAPL_2018 with 16901 tokens.
# Processed NASDAQ_AMAT_2014 with 2943 tokens.
# Processed NYSE_WAT_2017 with 4802 tokens.
# Processed NYSE_MDT_2019 with 16055 tokens.
# Processed NYSE_TDC_2014 with 17172 tokens.
# Processed NYSE_DTE_2014 with 15688 tokens.
# Processed NYSE_VMI_2016 with 1219 tokens.
# Processed NYSE_D_2017 with 16720 tokens.
# Processed NYSE_A_2016 with 15843 tokens.
# Processed NYSE_MTOR_2019 with 4673 tokens.
# Processed NYSE_DOW_2018 with 31440 tokens.
# Processed NASDAQ_ICFI_2017 with 4568 tokens.
# Processed NYSE_NOC_2011 with 13061 tokens.
# Processed NYSE_TT_2015 with 22132 tokens.
# Processed NASDAQ_FSLR_2017 with 15727 tokens.
# Processed NASDAQ_GILD_2019 with 11951 tokens.
# Processed NASDAQ_NTGR_2018 with 403 tokens.
# Processed NYSE_XOM_2011 with 21614 tokens.
# Processed NYSE_EMN_2011 with 17489 tokens.
# Processed NYSE_RIG_2016 with 7457 tokens.
# Processed NYSE_KMB_2004 with 16048 tokens.
# Processed NYSE_MSI_2015 with 3418 tokens.
# Processed NYSE_CBT_2012 with 8471 tokens.
# Processed NYSE_CLB_2018 with 12968 tokens.
# Processed NYSE_BTU_2017 with 16986 tokens.
# Processed NYSE_LXK_2010 with 25640 tokens.
# Processed NYSE_SPXC_2018 with 3404 tokens.
# Processed NYSE_HAL_2017 with 9203 tokens.
# Processed NYSE_GS_2013 with 2661 tokens.
# Processed NYSE_KEYS_2018 with 8319 tokens.
# Processed NYSE_B_2014 with 3113 tokens.
# Processed NYSE_MOS_2019 with 19414 tokens.
# Processed NYSE_VZ_2019 with 14852 tokens.
# Processed NYSE_ALB_2015 with 13677 tokens.
# Processed NYSE_SYY_2012 with 2186 tokens.
# Processed NYSE_DUK_2013 with 10833 tokens.
# Processed NYSE_MS_2013 with 22758 tokens.
# Processed NASDAQ_QRVO_2019 with 1779 tokens.
# Processed NYSE_IBM_2013 with 37057 tokens.
# Processed NYSE_COF_2019 with 40603 tokens.
# Processed NASDAQ_AMAT_2019 with 16688 tokens.
# Processed NYSE_VMI_2019 with 1252 tokens.
# Processed NYSE_LIN_2017 with 24767 tokens.
# Processed NASDAQ_FLIR_2019 with 4068 tokens.
# Processed NYSE_GIS_2010 with 21328 tokens.
# Processed NYSE_GIS_2015 with 39061 tokens.
# Processed NYSE_AXL_2019 with 5466 tokens.
# Processed NYSE_PG_2010 with 19885 tokens.
# Processed NYSE_RMD_2014 with 23999 tokens.
# Processed NYSE_NSC_2012 with 22720 tokens.
# Processed NYSE_NOC_2009 with 8453 tokens.
# Processed NYSE_CMC_2014 with 6147 tokens.
# Processed NYSE_WMT_2012 with 32562 tokens.
# Processed NYSE_ADM_2015 with 8742 tokens.
# Processed NYSE_HXL_2011 with 2178 tokens.
# Processed NYSE_UNM_2014 with 3184 tokens.
# Processed NYSE_CF_2016 with 4544 tokens.
# Processed NYSE_IPG_2016 with 16943 tokens.
# Processed NYSE_A_2001 with 11234 tokens.
# Processed NYSE_TDC_2016 with 14436 tokens.
# Processed NYSE_MSA_2019 with 4697 tokens.
# Processed NYSE_COP_2014 with 28435 tokens.
# Processed NASDAQ_SBUX_2012 with 3961 tokens.
# Processed NASDAQ_INTU_2018 with 4351 tokens.
# Processed NYSE_AES_2013 with 11955 tokens.
# Processed NYSE_IPG_2015 with 15899 tokens.
# Processed NYSE_LEA_2019 with 16879 tokens.
# Processed NYSE_WAT_2012 with 3049 tokens.
# Processed NYSE_ADM_2017 with 7907 tokens.
# Processed NYSE_XOM_2010 with 19558 tokens.
# Processed NYSE_CNX_2012 with 16487 tokens.
# Processed NYSE_TNC_2014 with 5510 tokens.
# Processed NYSE_LIN_2018 with 29827 tokens.
# Processed NYSE_HUM_2015 with 13165 tokens.
# Processed NYSE_TNC_2010 with 6605 tokens.
# Processed NYSE_DUK_2006 with 8370 tokens.
# Processed NYSE_COP_2019 with 40225 tokens.
# Processed NASDAQ_VRTX_2019 with 3166 tokens.
# Processed NYSE_WMT_2015 with 24211 tokens.
# Processed NYSE_SXT_2017 with 3535 tokens.
# Processed NYSE_AQUA_2016 with 3283 tokens.
# Processed NYSE_MMC_2019 with 6356 tokens.
# Processed NYSE_JLL_2009 with 23383 tokens.
# Processed NYSE_XOM_2014 with 23938 tokens.
# Processed NYSE_BAX_2016 with 16191 tokens.
# Processed NYSE_CBT_2018 with 9760 tokens.
# Processed NYSE_WHR_2016 with 7732 tokens.
# Processed NYSE_ABT_2015 with 24143 tokens.
# Processed NYSE_ESE_2019 with 1358 tokens.
# Processed NYSE_ES_2017 with 20633 tokens.
# Processed NASDAQ_TXN_2015 with 19625 tokens.
# Processed NYSE_CHD_2018 with 10352 tokens.
# Processed NYSE_GPC_2018 with 699 tokens.
# Processed NYSE_VAR_2012 with 7104 tokens.
# Processed NYSE_MSI_2014 with 15154 tokens.
# Processed NASDAQ_SBUX_2011 with 5250 tokens.
# Processed NYSE_WLK_2018 with 2147 tokens.
# Processed NYSE_DHR_2018 with 5426 tokens.
# Processed NYSE_CVX_2004 with 20860 tokens.
# Processed NYSE_FLS_2019 with 6771 tokens.
# Processed NYSE_DE_2019 with 26587 tokens.
# Processed NYSE_BDX_2009 with 12420 tokens.
# Processed NYSE_UNH_2019 with 11019 tokens.
# Processed NYSE_FMC_2017 with 8311 tokens.
# Processed NYSE_PG_2004 with 19896 tokens.
# Processed NYSE_BLL_2010 with 7008 tokens.
# Processed NYSE_TMO_2013 with 1907 tokens.
# Processed NYSE_SMG_2018 with 2348 tokens.
# Processed NYSE_ATR_2017 with 15824 tokens.
# Processed NASDAQ_CSCO_2014 with 39862 tokens.
# Processed NYSE_F_2019 with 17174 tokens.
# Processed NYSE_GD_2018 with 4919 tokens.
# Processed NASDAQ_RUN_2018 with 8141 tokens.
# Processed NYSE_COP_2006 with 24847 tokens.
# Processed NYSE_ABT_2018 with 20546 tokens.
# Processed NYSE_SYY_2018 with 17506 tokens.
# Processed NYSE_CL_2019 with 19265 tokens.
# Processed NYSE_CAT_2014 with 18639 tokens.
# Processed NYSE_OC_2013 with 972 tokens.
# Processed NYSE_WM_2009 with 13233 tokens.
# Processed NYSE_JLL_2018 with 21399 tokens.
# Processed NYSE_INGR_2012 with 1700 tokens.
# Processed NYSE_PRU_2019 with 12852 tokens.
# Processed NASDAQ_SBUX_2018 with 2105 tokens.
# Processed NYSE_TMO_2011 with 1658 tokens.
# Processed NYSE_TRV_2019 with 34794 tokens.
# Processed NYSE_MMC_2015 with 7127 tokens.
# Processed NYSE_H_2016 with 1510 tokens.
# Processed NYSE_IRM_2014 with 9816 tokens.
# Processed NYSE_NBL_2015 with 13318 tokens.
# Processed NYSE_ALB_2010 with 2777 tokens.
# Processed NYSE_TDC_2012 with 15057 tokens.
# Processed NYSE_NLSN_2018 with 31441 tokens.
# Processed NYSE_CRM_2014 with 3999 tokens.
# Processed NASDAQ_BIIB_2013 with 13385 tokens.
# Processed NYSE_A_2017 with 17475 tokens.
# Processed NYSE_CBT_2015 with 5698 tokens.
# Processed NASDAQ_GNTX_2016 with 3176 tokens.
# Processed NYSE_EMN_2018 with 13466 tokens.
# Processed NYSE_OC_2012 with 1156 tokens.
# Processed NASDAQ_ON_2012 with 5397 tokens.
# Processed NYSE_CVX_2009 with 17377 tokens.
# Processed NYSE_UNH_2017 with 2167 tokens.
# Processed NYSE_PH_2019 with 3909 tokens.
# Processed NYSE_OC_2010 with 930 tokens.
# Processed NYSE_NSC_2017 with 7046 tokens.
# Processed NYSE_AGN_2011 with 5251 tokens.
# Processed NYSE_COP_2017 with 12286 tokens.
# Processed NYSE_GS_2017 with 5601 tokens.
# Processed NASDAQ_SBUX_2016 with 3859 tokens.
# Processed NYSE_PBI_2011 with 8209 tokens.
# Processed NYSE_CSL_2019 with 3206 tokens.
# Processed NYSE_LXK_2011 with 26072 tokens.
# Processed NYSE_MOS_2018 with 18305 tokens.
# Processed NYSE_NOC_2019 with 16296 tokens.
# Processed NYSE_TNC_2019 with 12168 tokens.
# Processed NASDAQ_SPWR_2018 with 380 tokens.
# Processed NYSE_SCL_2019 with 5947 tokens.
# Processed NYSE_JBL_2017 with 7667 tokens.
# Processed NYSE_ATR_2019 with 20650 tokens.
# Processed NYSE_IRM_2016 with 6378 tokens.
# Processed NYSE_IVC_2019 with 2181 tokens.
# Processed NASDAQ_KLAC_2017 with 3820 tokens.
# Processed NYSE_MMM_2019 with 44098 tokens.
# Processed NYSE_ATO_2019 with 3969 tokens.
# Processed NYSE_BSX_2014 with 2992 tokens.
# Processed NYSE_CF_2019 with 3282 tokens.
# Processed NYSE_DAL_2019 with 20273 tokens.
# Processed NYSE_COP_2012 with 32066 tokens.
# Processed NYSE_ECL_2010 with 8222 tokens.
# Processed NYSE_IBM_2010 with 28247 tokens.
# Processed NYSE_PG_2007 with 22317 tokens.
# Processed NYSE_LXK_2016 with 25068 tokens.
# Processed NYSE_ALB_2016 with 19120 tokens.
# Processed NYSE_CPS_2017 with 12034 tokens.
# Processed NYSE_BA_2010 with 7203 tokens.
# Processed NYSE_MDT_2017 with 12382 tokens.
# Processed NYSE_NBL_2012 with 9762 tokens.
# Processed NYSE_NEM_2016 with 39225 tokens.
# Processed NYSE_APTV_2019 with 4423 tokens.
# Processed NYSE_WRI_2016 with 9095 tokens.
# Processed NYSE_LMT_2011 with 8979 tokens.
# Processed NYSE_ECL_2014 with 5484 tokens.
# Processed NYSE_BAX_2012 with 52060 tokens.
# Processed NYSE_CCL_2014 with 22855 tokens.
# Processed NYSE_NLSN_2016 with 21444 tokens.
# Processed NYSE_UNM_2012 with 3789 tokens.
# Processed NYSE_GM_2018 with 38401 tokens.
# Processed NYSE_OMC_2017 with 8860 tokens.
# Processed NYSE_NKE_2017 with 22013 tokens.
# Processed NYSE_BA_2008 with 6958 tokens.
# Processed NYSE_ACN_2013 with 12779 tokens.
# Processed NYSE_PG_2016 with 17487 tokens.
# Processed NYSE_SWK_2016 with 1416 tokens.
# Processed NASDAQ_KHC_2016 with 12047 tokens.
# Processed NASDAQ_UNFI_2017 with 2558 tokens.
# Processed NYSE_WMT_2014 with 35609 tokens.
# Processed NYSE_FDX_2010 with 7778 tokens.
# Processed NYSE_TT_2008 with 13531 tokens.
# Processed NYSE_CIEN_2018 with 9081 tokens.
# Processed NYSE_KEYS_2017 with 29241 tokens.
# Processed NYSE_APA_2019 with 30037 tokens.
# Processed NASDAQ_TRMB_2017 with 1539 tokens.
# Processed NYSE_BDX_2016 with 14909 tokens.
# Processed NASDAQ_STX_2013 with 8523 tokens.
# Processed NYSE_NPO_2018 with 4281 tokens.
# Processed NYSE_PBI_2008 with 5675 tokens.
# Processed NYSE_SLB_2015 with 3261 tokens.
# Processed NASDAQ_FITB_2019 with 26071 tokens.
# Processed NYSE_ECL_2016 with 4994 tokens.
# Processed NASDAQ_MYL_2017 with 16753 tokens.
# Processed NASDAQ_AMGN_2012 with 4524 tokens.
# Processed NYSE_DUK_2009 with 14939 tokens.
# Processed NASDAQ_MSFT_2015 with 17004 tokens.
# Processed NYSE_GIS_2019 with 23367 tokens.
# Processed NYSE_PG_1999 with 11015 tokens.
# Processed NYSE_PBI_2014 with 10101 tokens.
# Processed NYSE_WAT_2009 with 4145 tokens.
# Processed NASDAQ_CSCO_2018 with 40716 tokens.
# Processed NYSE_ABT_2013 with 23727 tokens.
# Processed NYSE_ORA_2013 with 6023 tokens.
# Processed NASDAQ_GRMN_2014 with 2093 tokens.
# Processed NYSE_DOW_2015 with 37057 tokens.
# Processed NASDAQ_DXCM_2019 with 4217 tokens.
# Processed NYSE_TT_2010 with 11047 tokens.
# Processed NYSE_ECL_2018 with 6752 tokens.
# Processed NASDAQ_COMM_2017 with 6744 tokens.
# Processed NYSE_COP_2015 with 11389 tokens.
# Processed NYSE_ABT_2012 with 32730 tokens.
# Processed NYSE_JBL_2016 with 3091 tokens.
# Processed NYSE_BDX_2011 with 11369 tokens.
# Processed NYSE_KMB_2015 with 10378 tokens.
# Processed NYSE_ACN_2011 with 10792 tokens.
# Processed NYSE_MMM_2013 with 26222 tokens.
# Processed NYSE_SPB_2017 with 3923 tokens.
# Processed NYSE_LEA_2018 with 12982 tokens.
# Processed NYSE_AXP_2018 with 16325 tokens.
# Processed NYSE_OC_2011 with 994 tokens.
# Processed NYSE_PG_2013 with 15696 tokens.
# Processed NYSE_ANET_2019 with 5770 tokens.
# Processed NYSE_APA_2016 with 14783 tokens.
# Processed NYSE_NKE_2013 with 24768 tokens.
# Processed NYSE_NOC_2018 with 15401 tokens.
# Processed NYSE_WRI_2019 with 10816 tokens.
# Processed NYSE_PII_2016 with 2195 tokens.
# Processed NYSE_MPC_2016 with 7486 tokens.
# Processed NYSE_ORA_2019 with 29479 tokens.
# Processed NYSE_IBM_2015 with 30921 tokens.
# Processed NYSE_CRM_2019 with 10702 tokens.
# Processed NYSE_ES_2016 with 16374 tokens.
# Processed NYSE_OC_2009 with 1051 tokens.
# Processed NASDAQ_AMGN_2018 with 7443 tokens.
# Processed NYSE_MMC_2006 with 2150 tokens.
# Processed NYSE_SLB_2014 with 15665 tokens.
# Processed NASDAQ_RUN_2017 with 7524 tokens.
# Processed NYSE_DUK_2008 with 15722 tokens.
# Processed NYSE_NEM_2015 with 36623 tokens.
# Processed NYSE_PII_2017 with 4809 tokens.
# Processed NYSE_TNC_2015 with 8224 tokens.
# Processed NYSE_CVX_2012 with 12035 tokens.
# Processed NYSE_WTS_2017 with 2280 tokens.
# Processed NYSE_LXK_2013 with 29052 tokens.
# Processed NYSE_TNC_2009 with 3406 tokens.
# Processed NYSE_CVX_2015 with 7650 tokens.
# Processed NYSE_TRV_2018 with 5831 tokens.
# Processed NYSE_SLB_2016 with 18887 tokens.
# Processed NASDAQ_FSLR_2018 with 17127 tokens.
# Processed NYSE_PII_2019 with 12228 tokens.
# Processed NYSE_VMW_2018 with 5758 tokens.
# Processed NYSE_WHR_2015 with 7779 tokens.
# Processed NYSE_HUM_2019 with 9308 tokens.
# Processed NYSE_HUM_2018 with 9564 tokens.
# Processed NASDAQ_MDLZ_2016 with 7849 tokens.
# Processed NYSE_SCS_2018 with 9527 tokens.
# Processed NASDAQ_STX_2019 with 15223 tokens.
# Processed NYSE_MHK_2016 with 3566 tokens.
# Processed NYSE_CAH_2017 with 5710 tokens.
# Processed NYSE_JLL_2012 with 13019 tokens.
# Processed NYSE_PVH_2015 with 8792 tokens.
# Processed NYSE_CMI_2012 with 26366 tokens.
# Processed NYSE_DUK_2017 with 12300 tokens.
# Processed NYSE_LMT_2018 with 13168 tokens.
# Processed NYSE_AXP_2015 with 13677 tokens.
# Processed NYSE_FDX_2014 with 18584 tokens.
# Processed NYSE_BTU_2012 with 12925 tokens.
# Processed NYSE_LMT_2014 with 26881 tokens.
# Processed NYSE_JNJ_2012 with 30452 tokens.
# Processed NYSE_SWK_2013 with 1528 tokens.
# Processed NASDAQ_SBUX_2007 with 25978 tokens.
# Processed NYSE_FDX_2012 with 22053 tokens.
# Processed NYSE_PG_2001 with 16061 tokens.
# Processed NYSE_CNX_2019 with 10296 tokens.
# Processed NYSE_ECL_2005 with 4114 tokens.
# Processed NYSE_LII_2019 with 7654 tokens.
# Processed NYSE_DUK_2018 with 12441 tokens.
# Processed NYSE_GS_2009 with 7442 tokens.
# Processed NYSE_MS_2011 with 16367 tokens.
# Processed NYSE_CBT_2014 with 13150 tokens.
# Processed NYSE_CVX_2013 with 4704 tokens.
# Processed NYSE_HAL_2016 with 8229 tokens.
# Processed NYSE_SXC_2019 with 6120 tokens.
# Processed NYSE_PG_2014 with 17854 tokens.
# Processed NYSE_VZ_2015 with 12056 tokens.
# Processed NASDAQ_MYL_2016 with 12230 tokens.
# Processed NYSE_COP_2005 with 12730 tokens.
# Processed NYSE_CCL_2011 with 20012 tokens.
# Processed NYSE_BLL_2016 with 8679 tokens.
# Processed NYSE_TDC_2015 with 15249 tokens.
# Processed NYSE_ECL_2012 with 4774 tokens.
# Processed NYSE_TSN_2007 with 13528 tokens.
# Processed NYSE_PG_2006 with 21814 tokens.
# Processed NASDAQ_CSCO_2017 with 43378 tokens.
# Processed NYSE_XOM_2012 with 24202 tokens.
# Processed NASDAQ_GRMN_2019 with 3445 tokens.
# Processed NASDAQ_CSCO_2012 with 50336 tokens.
# Processed NYSE_BDX_2008 with 2792 tokens.
# Processed NYSE_GPC_2019 with 4914 tokens.
# Processed NYSE_AIV_2019 with 1333 tokens.
# Processed NYSE_WM_2011 with 5541 tokens.
# Processed NYSE_MIC_2019 with 4292 tokens.
# Processed NYSE_PBI_2015 with 11390 tokens.
# Processed NYSE_LMT_2012 with 16223 tokens.
# Processed NYSE_MSI_2018 with 6908 tokens.
# Processed NYSE_HPE_2017 with 16883 tokens.
# Processed NYSE_PVH_2017 with 9548 tokens.
# Processed NYSE_DUK_2019 with 12505 tokens.
# Processed NASDAQ_GNTX_2019 with 3784 tokens.
# Processed NYSE_APA_2017 with 26013 tokens.
# Processed NASDAQ_REGN_2019 with 14511 tokens.
# Processed NASDAQ_SLAB_2019 with 2638 tokens.
# Processed NYSE_WAT_2014 with 3725 tokens.
# Processed NYSE_PG_2008 with 23453 tokens.
# Processed NYSE_FMC_2018 with 9952 tokens.
# Processed NYSE_TSN_2019 with 27250 tokens.
# Processed NYSE_CLB_2019 with 10924 tokens.
# Processed NYSE_PRU_2016 with 9683 tokens.
# Processed NYSE_BSX_2018 with 12539 tokens.
# Processed NYSE_NKE_2019 with 25469 tokens.
# Processed NASDAQ_EBAY_2017 with 3149 tokens.
# Processed NYSE_SYY_2007 with 4050 tokens.
# Processed NYSE_ITW_2016 with 4040 tokens.
# Processed NASDAQ_SPWR_2017 with 349 tokens.
# Processed NYSE_EMN_2015 with 19886 tokens.
# Processed NYSE_ECL_2015 with 5253 tokens.
# Processed NYSE_LMT_2013 with 19236 tokens.
# Processed NYSE_VAR_2011 with 8552 tokens.
# Processed NYSE_BKR_2019 with 10014 tokens.
# Processed NYSE_TSN_2014 with 526 tokens.
# Processed NYSE_KO_2017 with 2584 tokens.
# Processed NYSE_CHD_2016 with 6422 tokens.
# Processed NYSE_HAL_2018 with 12492 tokens.
# Processed NYSE_OIS_2019 with 5013 tokens.
# Processed NYSE_CNX_2014 with 12739 tokens.
# Processed NYSE_JNJ_2017 with 51763 tokens.
# Processed NYSE_UNM_2015 with 3839 tokens.
# Processed NYSE_COF_2016 with 13446 tokens.
# Processed NYSE_GS_2014 with 9163 tokens.
# Processed NYSE_ADM_2016 with 8043 tokens.
# Processed NYSE_ESE_2016 with 3541 tokens.
# Processed NASDAQ_SBUX_2015 with 2241 tokens.
# Processed NYSE_CHD_2017 with 8884 tokens.
# Processed NYSE_WHR_2012 with 4773 tokens.
# Processed NYSE_ITW_2017 with 4716 tokens.
# Processed NYSE_UNM_2018 with 4961 tokens.
# Processed NYSE_XYL_2018 with 14877 tokens.
# Processed NASDAQ_ADSK_2019 with 3367 tokens.
# Processed NYSE_PG_2011 with 19715 tokens.
# Processed NYSE_ACCO_2018 with 4497 tokens.
# Processed NYSE_NKE_2001 with 17513 tokens.
# Processed NASDAQ_IOSP_2014 with 6130 tokens.
# Processed NYSE_SYY_2010 with 1320 tokens.
# Processed NYSE_HIG_2014 with 10092 tokens.
# Processed NYSE_ITW_2012 with 5902 tokens.
# Processed NASDAQ_SWKS_2019 with 3199 tokens.
# Processed NYSE_XRX_2016 with 22841 tokens.
# Processed NYSE_VZ_2006 with 8789 tokens.
# Processed NASDAQ_BIIB_2017 with 11278 tokens.
# Processed NYSE_SCS_2013 with 9632 tokens.
# Processed NYSE_SYY_2008 with 1159 tokens.
# Processed NYSE_IEX_2018 with 5846 tokens.
# Processed NYSE_TSE_2018 with 9985 tokens.
# Processed NYSE_WFC_2016 with 2976 tokens.
# Processed NYSE_TMO_2014 with 2717 tokens.
# Processed NYSE_HPE_2018 with 18577 tokens.
# Processed NYSE_KO_2019 with 19267 tokens.
# Processed NYSE_MSI_2019 with 8475 tokens.
# Processed NYSE_TNC_2017 with 10542 tokens.
# Processed NYSE_A_2002 with 15908 tokens.
# Processed NYSE_SO_2017 with 5227 tokens.
# Processed NYSE_KRA_2018 with 8098 tokens.
# Processed NYSE_AWK_2019 with 30494 tokens.
# Processed NYSE_BKD_2017 with 4680 tokens.
# Processed NYSE_RIG_2018 with 7217 tokens.
# Processed NYSE_T_2010 with 7188 tokens.
# Processed NYSE_ICE_2019 with 2114 tokens.
# Processed NYSE_XOM_2019 with 8726 tokens.
# Processed NYSE_WFC_2018 with 10652 tokens.
# Processed NYSE_A_2019 with 13178 tokens.
# Processed NYSE_ORA_2011 with 5849 tokens.
# Processed NYSE_IP_2015 with 2225 tokens.
# Processed NYSE_T_2013 with 2384 tokens.
# Processed NYSE_PBI_2019 with 16219 tokens.
# Processed NYSE_HPE_2019 with 21686 tokens.
# Processed NYSE_MA_2018 with 17595 tokens.
# Processed NYSE_RSG_2017 with 3118 tokens.
# Processed NYSE_CAH_2019 with 12224 tokens.
# Processed NYSE_SMG_2019 with 3033 tokens.
# Processed NYSE_DUK_2010 with 17123 tokens.
# Processed NYSE_MHK_2017 with 3021 tokens.
# Processed NYSE_IQV_2013 with 6411 tokens.
# Processed NYSE_INGR_2017 with 3967 tokens.
# Processed NYSE_TSN_2005 with 13504 tokens.
# Processed NYSE_SYY_2013 with 391 tokens.
# Processed NYSE_EMN_2014 with 26696 tokens.
# Processed NYSE_A_2004 with 19976 tokens.
# Processed NYSE_OSK_2015 with 7401 tokens.
# Processed NYSE_MOS_2017 with 16873 tokens.
# Processed NYSE_CAT_2016 with 12753 tokens.
# Processed NYSE_WRI_2017 with 2037 tokens.
# Processed NYSE_WM_2015 with 32227 tokens.
# Processed NYSE_TT_2016 with 13157 tokens.
# Processed NYSE_VZ_2010 with 9475 tokens.
# Processed NYSE_CMC_2018 with 8669 tokens.
# Processed NYSE_COF_2017 with 13574 tokens.
# Processed NASDAQ_CREE_2019 with 10916 tokens.
# Processed NYSE_AIG_2015 with 3534 tokens.
# Processed NASDAQ_AMGN_2011 with 1490 tokens.
# Processed NYSE_POR_2018 with 994 tokens.
# Processed NYSE_BAX_2019 with 20500 tokens.
# Processed NYSE_ALB_2007 with 2897 tokens.
# Processed NYSE_IBM_2004 with 42059 tokens.
# Processed NYSE_DCI_2012 with 2774 tokens.
# Processed NYSE_PG_2003 with 18759 tokens.
# Processed NYSE_CCL_2017 with 33677 tokens.
# Processed NASDAQ_FLIR_2018 with 4094 tokens.
# Processed NYSE_WM_2014 with 1690 tokens.
# Processed NYSE_BAX_2014 with 43992 tokens.
# Processed NYSE_BBY_2015 with 7150 tokens.
# Processed NYSE_JLL_2014 with 4988 tokens.
# Processed NYSE_CMI_2014 with 33445 tokens.
# Processed NASDAQ_CSCO_2009 with 53199 tokens.
# Processed NASDAQ_MYL_2019 with 27299 tokens.
# Processed NYSE_IBM_2017 with 16281 tokens.
# Processed NYSE_POR_2019 with 1093 tokens.
# Processed NYSE_FDX_2016 with 11821 tokens.
# Processed NYSE_DTE_2019 with 9948 tokens.
# Processed NASDAQ_AMAT_2016 with 3819 tokens.
# Processed NYSE_TMO_2015 with 3220 tokens.
# Processed NYSE_ALB_2011 with 4225 tokens.
# Processed NYSE_WNC_2019 with 5561 tokens.
# Processed NASDAQ_INFN_2015 with 9484 tokens.
# Processed NYSE_KRA_2016 with 5419 tokens.
# Processed NYSE_H_2017 with 1472 tokens.
# Processed NYSE_BMY_2009 with 2218 tokens.
# Processed NASDAQ_MIDD_2019 with 3252 tokens.
# Processed NYSE_PG_2019 with 36715 tokens.
# Processed NASDAQ_SBUX_2001 with 5837 tokens.
# Processed NYSE_CCL_2012 with 26956 tokens.
# Processed NYSE_BSX_2017 with 6240 tokens.
# Processed NYSE_COP_2018 with 36763 tokens.
# Processed NYSE_AIV_2018 with 1268 tokens.
# Processed NYSE_XOM_2015 with 31095 tokens.
# Processed NYSE_PEB_2019 with 5813 tokens.
# Processed NYSE_KMB_2009 with 18320 tokens.
# Processed NYSE_MOS_2015 with 1746 tokens.
# Processed NYSE_BSX_2015 with 3697 tokens.
# Processed NYSE_INGR_2019 with 7506 tokens.
# Processed NASDAQ_AMGN_2013 with 4346 tokens.
# Processed NYSE_IPG_2019 with 17924 tokens.
# Processed NYSE_FDX_2008 with 13170 tokens.
# Processed NYSE_NI_2018 with 1632 tokens.
# Processed NYSE_DAN_2017 with 3349 tokens.
# Processed NYSE_KO_2016 with 2923 tokens.
# Processed NYSE_ICE_2017 with 7402 tokens.
# Processed NASDAQ_MSFT_2005 with 6391 tokens.
# Processed NYSE_BSX_2019 with 18170 tokens.
# Processed NYSE_ABT_2017 with 37173 tokens.
# Processed NYSE_A_2006 with 9299 tokens.
# Processed NYSE_TKR_2018 with 9101 tokens.
# Processed NASDAQ_SWKS_2018 with 3045 tokens.
# Processed NYSE_LMT_2019 with 17597 tokens.
# Processed NYSE_FMC_2013 with 11228 tokens.
# Processed NYSE_MOS_2014 with 1307 tokens.
# Processed NYSE_IBM_2008 with 10054 tokens.
# Processed NYSE_ATR_2018 with 17258 tokens.
# Processed NYSE_GS_2019 with 15487 tokens.
# Processed NYSE_JEC_2010 with 15348 tokens.
# Processed NYSE_NKE_2018 with 22147 tokens.
# Processed NYSE_CAT_2012 with 14248 tokens.
# Processed NYSE_LLY_2018 with 17712 tokens.
# Processed NASDAQ_STX_2009 with 7025 tokens.
# Processed NYSE_RMD_2011 with 23531 tokens.
# Processed NYSE_VZ_2018 with 9951 tokens.
# Processed NASDAQ_ADSK_2017 with 5805 tokens.
# Processed NYSE_MMC_2010 with 5164 tokens.
# Processed NYSE_CL_2018 with 20467 tokens.
# Processed NYSE_JBL_2013 with 17480 tokens.
# Processed NYSE_APA_2018 with 31395 tokens.
# Processed NYSE_VZ_2013 with 15167 tokens.
# Processed NYSE_IRM_2018 with 10339 tokens.
# Processed NYSE_JNJ_2010 with 20247 tokens.
# Processed NYSE_PG_2018 with 30462 tokens.
# Processed NYSE_HIG_2016 with 2543 tokens.
# Processed NASDAQ_CSIQ_2018 with 14254 tokens.
# Processed NYSE_VAL_2019 with 2942 tokens.
# Processed NYSE_WTS_2019 with 11585 tokens.
# Processed NYSE_IPG_2018 with 17614 tokens.
# Processed NYSE_DCI_2014 with 2992 tokens.
# Processed NYSE_TT_2009 with 12650 tokens.
# Processed NYSE_VAR_2016 with 6640 tokens.
# Processed NYSE_VZ_2011 with 9894 tokens.
# Processed NYSE_ORA_2015 with 4542 tokens.
# Processed NYSE_BA_2019 with 5682 tokens.
# Processed NYSE_BA_2009 with 10376 tokens.
# Processed NYSE_VMW_2015 with 9201 tokens.
# Processed NASDAQ_MDLZ_2019 with 14018 tokens.
# Processed NYSE_KMB_2006 with 15101 tokens.
# Processed NYSE_H_2014 with 897 tokens.
# Processed NYSE_OC_2006 with 3467 tokens.
# Processed NYSE_DGX_2016 with 9798 tokens.
# Processed NYSE_CMI_2005 with 12981 tokens.
# Processed NYSE_APD_2017 with 18341 tokens.
# Processed NYSE_SCS_2017 with 9333 tokens.
# Processed NYSE_AES_2015 with 15297 tokens.
# Processed NYSE_B_2019 with 5867 tokens.
# Processed NYSE_AES_2014 with 16177 tokens.
# Processed NYSE_OC_2007 with 6069 tokens.
# Processed NYSE_ATR_2013 with 1584 tokens.
# Processed NYSE_CCL_2015 with 23408 tokens.
# Processed NYSE_LEA_2014 with 3212 tokens.
# Processed NASDAQ_BIIB_2018 with 12163 tokens.
# Processed NYSE_INGR_2013 with 1727 tokens.
# Processed NYSE_BMY_2018 with 7506 tokens.
# Processed NYSE_ECL_2008 with 5918 tokens.
# Processed NYSE_HCC_2019 with 3153 tokens.
# Processed NYSE_ADM_2019 with 10045 tokens.
# Processed NYSE_NKE_2009 with 39506 tokens.
# Processed NYSE_KMB_2012 with 20257 tokens.
# Processed NYSE_FDX_2011 with 12014 tokens.
# Processed NYSE_ACN_2017 with 15967 tokens.
# Processed NYSE_PII_2015 with 1728 tokens.
# Processed NASDAQ_CDNS_2018 with 3118 tokens.
# Processed NYSE_OC_2017 with 51300 tokens.
# Processed NYSE_CAT_2015 with 17496 tokens.
# Processed NYSE_AQUA_2018 with 1945 tokens.
# Processed NYSE_HIG_2018 with 6225 tokens.
# Processed NYSE_ABT_2019 with 25875 tokens.
# Processed NYSE_FDX_2018 with 14382 tokens.
# Processed NYSE_ES_2015 with 10405 tokens.
# Processed NYSE_BDX_2012 with 13990 tokens.
# Processed NYSE_BTU_2016 with 18389 tokens.
# Processed NYSE_JLL_2013 with 5002 tokens.
# Processed NYSE_INGR_2011 with 1850 tokens.
# Processed NYSE_UNH_2018 with 2186 tokens.
# Processed NYSE_CCL_2018 with 32652 tokens.
# Processed NYSE_H_2015 with 949 tokens.
# Processed NASDAQ_NDAQ_2017 with 8643 tokens.
# Processed NYSE_TMO_2012 with 4674 tokens.
# Processed NYSE_A_2015 with 16049 tokens.
# Processed NYSE_LIN_2019 with 31532 tokens.
# Processed NYSE_BDX_2019 with 19517 tokens.
# Processed NYSE_LII_2016 with 2162 tokens.
# Processed NYSE_ITW_2018 with 6034 tokens.
# Processed NYSE_GLT_2019 with 4987 tokens.
# Processed NYSE_ORCL_2006 with 5369 tokens.
# Processed NYSE_WMT_2018 with 12659 tokens.
# Processed NYSE_MAS_2009 with 13598 tokens.
# Processed NYSE_GS_2006 with 3408 tokens.
# Processed NYSE_VMI_2014 with 3570 tokens.
# Processed NASDAQ_MSFT_2014 with 14389 tokens.
# Processed NYSE_TKR_2019 with 5444 tokens.
# Processed NASDAQ_BIIB_2019 with 18225 tokens.
# Processed NYSE_GIS_2009 with 12969 tokens.
# Processed NASDAQ_EBAY_2018 with 4223 tokens.
# Processed NASDAQ_SPWR_2019 with 579 tokens.
# Processed NYSE_DTE_2016 with 14929 tokens.
# Processed NYSE_IBM_2018 with 11763 tokens.
# Processed NYSE_MS_2017 with 7679 tokens.
# Processed NASDAQ_CSCO_2013 with 51069 tokens.
# Processed NYSE_MS_2015 with 13833 tokens.
# Processed NYSE_IBM_2014 with 32221 tokens.
# Processed NASDAQ_NDAQ_2018 with 8473 tokens.
# Processed NYSE_DCI_2019 with 1500 tokens.
# Processed NYSE_CBT_2017 with 9709 tokens.
# Processed NASDAQ_STX_2011 with 8221 tokens.
# Processed NYSE_INGR_2014 with 2686 tokens.
# Processed NYSE_XYL_2019 with 23467 tokens.
# Processed NYSE_LMT_2017 with 12389 tokens.
# Processed NYSE_MPC_2012 with 8929 tokens.
# Processed NYSE_MPC_2017 with 5632 tokens.
# Processed NYSE_UNH_2015 with 3051 tokens.
# Processed NYSE_B_2016 with 3267 tokens.
# Processed NYSE_NSC_2008 with 10550 tokens.
# Processed NASDAQ_ICFI_2013 with 8667 tokens.
# Processed NYSE_BA_2011 with 7491 tokens.
# Processed NYSE_CMI_2011 with 21773 tokens.
# Processed NYSE_DUK_2015 with 10744 tokens.
# Processed NYSE_MSI_2016 with 3593 tokens.
# Processed NYSE_CL_2017 with 18438 tokens.
# Processed NASDAQ_ICFI_2018 with 6822 tokens.
# Processed NYSE_LLY_2012 with 35524 tokens.
# Processed NYSE_T_2008 with 14487 tokens.
# Processed NYSE_LXK_2015 with 25039 tokens.
# Processed NYSE_MA_2017 with 14123 tokens.
# Processed NYSE_ADM_2018 with 7580 tokens.
# Processed NYSE_PG_2005 with 21696 tokens.
# Processed NASDAQ_WDC_2018 with 11498 tokens.
# Processed NYSE_FDX_2013 with 15485 tokens.
# Processed NYSE_LXK_2007 with 5835 tokens.
# Processed NYSE_UNM_2008 with 3300 tokens.
# Processed NYSE_CVX_2005 with 12321 tokens.
# Processed NYSE_SYK_2019 with 2763 tokens.
# Processed NYSE_GE_2019 with 714 tokens.
# Processed NYSE_SWK_2014 with 1276 tokens.
# Processed NYSE_WM_2017 with 43603 tokens.
# Processed NYSE_GTI_2019 with 3590 tokens.
# Processed NYSE_WRI_2018 with 3295 tokens.
# Processed NYSE_DUK_2011 with 13602 tokens.
# Processed NYSE_EMN_2013 with 4524 tokens.
# Processed NYSE_T_2009 with 11593 tokens.
# Processed NYSE_IBM_2012 with 33387 tokens.
# Processed NYSE_JNJ_2016 with 31219 tokens.
# Processed NYSE_A_2009 with 3344 tokens.
# Processed NYSE_ECL_2011 with 4396 tokens.
# Processed NYSE_BAX_2018 with 18328 tokens.
# Processed NYSE_FMC_2012 with 11451 tokens.
# Processed NYSE_TXT_2018 with 4674 tokens.
# Processed NYSE_CRM_2012 with 4713 tokens.
# Processed NYSE_EMN_2016 with 11004 tokens.
# Processed NYSE_INGR_2018 with 4350 tokens.
# Processed NYSE_A_2011 with 11302 tokens.
# Processed NYSE_GIS_2014 with 29662 tokens.
# Processed NYSE_SCS_2015 with 5377 tokens.
# Processed NYSE_KO_2018 with 18846 tokens.
# Processed NYSE_IBM_2006 with 19437 tokens.
# Processed NYSE_CMI_2015 with 28801 tokens.
# Processed NYSE_A_2014 with 13625 tokens.
# Processed NYSE_JEC_2009 with 6753 tokens.
# Processed NYSE_KMB_2008 with 15718 tokens.
# Processed NYSE_PG_2002 with 16998 tokens.
# Processed NYSE_APA_2013 with 9036 tokens.
# Processed NYSE_OC_2018 with 50789 tokens.
# Processed NYSE_MAS_2003 with 9801 tokens.
# Processed NASDAQ_AMAT_2017 with 5964 tokens.
# Processed NYSE_KMB_2017 with 13702 tokens.
# Processed NYSE_LXK_2014 with 31948 tokens.
# Processed NASDAQ_AMGN_2015 with 4069 tokens.
# Processed NYSE_WRI_2014 with 8044 tokens.
# Processed NASDAQ_ICFI_2014 with 13018 tokens.
# Processed NYSE_CMI_2006 with 17759 tokens.
# Processed NYSE_CBT_2019 with 11440 tokens.
# Processed NYSE_TT_2018 with 17258 tokens.
# Processed NYSE_H_2013 with 11244 tokens.
# Processed NYSE_MAS_2018 with 6409 tokens.
# Processed NYSE_WM_2016 with 1645 tokens.
# Processed NYSE_BMY_2014 with 12269 tokens.
# Processed NYSE_SPXC_2019 with 5730 tokens.
# Processed NYSE_PBI_2010 with 8039 tokens.
# Processed NYSE_BMY_2013 with 1702 tokens.
# Processed NYSE_CBT_2016 with 9456 tokens.
# Processed NASDAQ_ICFI_2016 with 7670 tokens.
# Processed NYSE_IRM_2017 with 10207 tokens.
# Processed NASDAQ_SONO_2019 with 1833 tokens.
# Processed NYSE_LII_2018 with 2060 tokens.
# Processed NYSE_ITW_2015 with 8146 tokens.
# Processed NYSE_DAN_2019 with 10425 tokens.
# Processed NYSE_CL_2014 with 15825 tokens.
# Processed NYSE_DHR_2019 with 9754 tokens.
# Processed NYSE_IBM_2009 with 10901 tokens.
# Processed NYSE_MAS_2015 with 4425 tokens.
# Processed NYSE_MOS_2012 with 10588 tokens.
# Processed NYSE_A_2000 with 5877 tokens.
# Processed NYSE_CNX_2017 with 7496 tokens.
# Processed NASDAQ_SBUX_2017 with 3984 tokens.
# Processed NYSE_CVX_2017 with 7557 tokens.
# Processed NYSE_HI_2019 with 4205 tokens.
# Processed NYSE_IQV_2015 with 1132 tokens.
# Processed NYSE_KMB_2010 with 25914 tokens.
# Processed NYSE_CB_2018 with 90137 tokens.
# Processed NYSE_LLY_2019 with 21440 tokens.
# Processed NYSE_PBI_2018 with 14279 tokens.
# Processed NYSE_JEC_2015 with 14609 tokens.
# Processed NYSE_ITW_2013 with 6607 tokens.
# Processed NYSE_BAX_2013 with 43594 tokens.
# Processed NYSE_NI_2019 with 1759 tokens.
# Processed NYSE_MIC_2018 with 2455 tokens.
# Processed NYSE_WM_2019 with 20689 tokens.
# Processed NASDAQ_STX_2008 with 8168 tokens.
# Processed NYSE_ITW_2010 with 2693 tokens.
# Processed NYSE_MMM_2016 with 44784 tokens.
# Processed NASDAQ_AMGN_2017 with 6631 tokens.
# Processed NYSE_CF_2017 with 6197 tokens.
# Processed NASDAQ_CLNE_2016 with 8610 tokens.
# Processed NYSE_B_2015 with 3600 tokens.
# Processed NYSE_JLL_2011 with 21411 tokens.
# Processed NYSE_PH_2016 with 3155 tokens.
# Processed NYSE_IRM_2019 with 9655 tokens.
# Processed NYSE_KMB_2003 with 9251 tokens.
# Processed NASDAQ_EBAY_2019 with 6920 tokens.
# Processed NYSE_BA_2015 with 11765 tokens.
# Processed NYSE_DD_2015 with 4250 tokens.
# Processed NYSE_AES_2019 with 18190 tokens.
# Processed NYSE_BA_2013 with 7495 tokens.
# Processed NASDAQ_CTXS_2018 with 2371 tokens.
# Processed NYSE_CF_2018 with 3349 tokens.
# Processed NYSE_INGR_2015 with 3269 tokens.
# Processed NYSE_HAL_2019 with 16216 tokens.
# Processed NYSE_CMI_2010 with 23725 tokens.
# Processed NYSE_WMT_2009 with 24832 tokens.
# Processed NYSE_BC_2019 with 11042 tokens.
# Processed NYSE_TMO_2018 with 2471 tokens.
# Processed NYSE_SSD_2019 with 3074 tokens.
# Processed NYSE_BAX_2009 with 7390 tokens.
# Processed NASDAQ_TXN_2012 with 4031 tokens.
# Processed NYSE_AIG_2019 with 10487 tokens.
# Processed NYSE_MMM_2014 with 32930 tokens.
# Processed NYSE_KMB_2013 with 17387 tokens.
# Processed NYSE_GM_2017 with 37354 tokens.
# Processed NYSE_AGN_2015 with 7885 tokens.
# Processed NYSE_MPC_2013 with 9503 tokens.
# Processed NYSE_ITW_2011 with 4283 tokens.
# Processed NASDAQ_VECO_2019 with 3139 tokens.
# Processed NYSE_LEA_2017 with 3404 tokens.
# Processed NYSE_NSC_2009 with 12905 tokens.
# Processed NYSE_BA_2018 with 7162 tokens.
# Processed NYSE_ACN_2018 with 14405 tokens.
# Processed NYSE_NKE_2004 with 26473 tokens.
# Processed NYSE_BHC_2018 with 7018 tokens.
# Processed NYSE_CVX_2016 with 7897 tokens.
# Processed NYSE_EMN_2017 with 10778 tokens.
# Processed NYSE_PFE_2007 with 24228 tokens.
# Processed NYSE_DCI_2013 with 3293 tokens.
# Processed NASDAQ_REGN_2017 with 8603 tokens.
# Processed NYSE_GIS_2017 with 28252 tokens.
# Processed NYSE_MOS_2009 with 1866 tokens.
# Processed NYSE_NKE_2015 with 26295 tokens.
# Processed NASDAQ_SBUX_2004 with 13915 tokens.
# Processed NYSE_JEC_2011 with 14574 tokens.
# Processed NYSE_GM_2019 with 40810 tokens.
# Processed NYSE_MPC_2015 with 8151 tokens.
# Processed NYSE_AROC_2018 with 4068 tokens.
# Processed NYSE_DNOW_2019 with 5927 tokens.
# Processed NASDAQ_ACIW_2019 with 3212 tokens.
# Processed NYSE_CVX_2008 with 16047 tokens.
# Processed NYSE_DGX_2017 with 10061 tokens.
# Processed NYSE_CB_2016 with 87049 tokens.
# Processed NYSE_MMM_2015 with 38636 tokens.
# Processed NASDAQ_TXN_2014 with 16013 tokens.
# Processed NYSE_MAN_2015 with 8479 tokens.
# Processed NYSE_SWK_2019 with 1653 tokens.
# Processed NYSE_JNJ_2018 with 2558 tokens.
# Processed NYSE_BA_2012 with 6479 tokens.
# Processed NASDAQ_COMM_2013 with 6088 tokens.
# Processed NYSE_T_2016 with 2626 tokens.
# Processed NYSE_FMC_2011 with 10450 tokens.
# Processed NYSE_NBL_2014 with 9477 tokens.
# Processed NYSE_ECL_2019 with 5510 tokens.
# Processed NASDAQ_AAPL_2014 with 5936 tokens.
# Processed NYSE_FMC_2014 with 9202 tokens.
# Processed NYSE_SWK_2018 with 1548 tokens.
# Processed NASDAQ_TSLA_2019 with 8905 tokens.
# Processed NYSE_MAN_2018 with 1861 tokens.
# Processed NASDAQ_NDAQ_2019 with 12728 tokens.
# Processed NASDAQ_ON_2017 with 14600 tokens.
# Processed NYSE_IRM_2015 with 11027 tokens.
# Processed NYSE_CAT_2013 with 18116 tokens.
# Processed NYSE_APA_2012 with 6375 tokens.
# Processed NYSE_AIG_2017 with 3244 tokens.
# Processed NYSE_LXK_2017 with 25102 tokens.
# Processed NYSE_NOC_2007 with 8589 tokens.
# Processed NYSE_VAR_2013 with 8990 tokens.
# Processed NASDAQ_NTGR_2019 with 372 tokens.
# Processed NYSE_BBY_2019 with 10717 tokens.
# Processed NYSE_NEM_2018 with 44351 tokens.
# Processed NYSE_ORCL_2018 with 13322 tokens.
# Processed NYSE_H_2012 with 3745 tokens.
# Processed NYSE_WAT_2019 with 3366 tokens.
# Processed NYSE_MAS_2017 with 6739 tokens.
# Processed NYSE_MS_2018 with 10176 tokens.
# Processed NYSE_SPXC_2017 with 916 tokens.
# Processed NASDAQ_IDXX_2018 with 3821 tokens.
# Processed NYSE_LLY_2017 with 14511 tokens.
# Processed NYSE_BAX_2007 with 10445 tokens.
# Processed NYSE_SYY_2009 with 1527 tokens.
# Processed NYSE_OC_2019 with 69139 tokens.
# Processed NYSE_NI_2015 with 973 tokens.
# Processed NYSE_LEA_2015 with 3815 tokens.
# Processed NYSE_ATR_2015 with 4580 tokens.
# Processed NYSE_BAX_2008 with 6558 tokens.
# Processed NYSE_RMD_2013 with 23471 tokens.
# Processed NASDAQ_STX_2006 with 12940 tokens.
# Processed NYSE_VZ_2004 with 8654 tokens.
# Processed NYSE_PRU_2014 with 8283 tokens.
# Processed NASDAQ_STX_2016 with 12653 tokens.
# Processed NYSE_SYY_2019 with 20553 tokens.
# Processed NYSE_LLY_2015 with 9651 tokens.
# Processed NYSE_MHK_2019 with 7752 tokens.
# Processed NASDAQ_BIIB_2014 with 18325 tokens.
# Processed NYSE_FMC_2019 with 11414 tokens.
# Processed NYSE_LEA_2016 with 4320 tokens.
# Processed NYSE_LMT_2015 with 19180 tokens.
# Processed NYSE_ICE_2018 with 7035 tokens.
# Processed NYSE_MDT_2016 with 11726 tokens.
# Processed NYSE_NBL_2016 with 12008 tokens.
# Processed NASDAQ_ICFI_2015 with 12981 tokens.
# Processed NASDAQ_MDLZ_2014 with 9099 tokens.
# Processed NYSE_F_2017 with 29873 tokens.
# Processed NYSE_MMC_2014 with 7284 tokens.
# Processed NYSE_TT_2006 with 9302 tokens.
# Processed NYSE_WMT_2017 with 32984 tokens.
# Processed NYSE_COP_2008 with 9094 tokens.
# Processed NYSE_CMI_2003 with 7129 tokens.
# Processed NASDAQ_COMM_2015 with 2200 tokens.
# Processed NYSE_AES_2018 with 14188 tokens.
# Processed NYSE_MMM_2012 with 23190 tokens.
# Processed NYSE_HAL_2015 with 10216 tokens.
# Processed NYSE_GIS_2011 with 18839 tokens.
# Processed NYSE_COP_2013 with 30170 tokens.
# Processed NYSE_GTES_2019 with 3564 tokens.
# Processed NYSE_PG_2017 with 27988 tokens.
# Processed NYSE_TMO_2017 with 2491 tokens.
# Processed NYSE_NI_2017 with 1758 tokens.
# Processed NYSE_KMB_2011 with 24654 tokens.
# Processed NYSE_NOC_2008 with 10377 tokens.
# Processed NYSE_NBL_2013 with 9851 tokens.
# Processed NASDAQ_NTGR_2017 with 685 tokens.
# Processed NYSE_IPG_2017 with 17423 tokens.
# Processed NASDAQ_UNFI_2015 with 1896 tokens.
# Processed NYSE_CMI_2017 with 10121 tokens.
# Processed NYSE_RHT_2019 with 3097 tokens.
# Processed NYSE_PBI_2013 with 9734 tokens.
# Processed NYSE_ACN_2019 with 15489 tokens.
# Processed NYSE_BDX_2010 with 11579 tokens.
# Processed NASDAQ_MSFT_2012 with 11794 tokens.
# Processed NYSE_LLY_2010 with 4352 tokens.
# Processed NYSE_GIS_2016 with 33330 tokens.
# Processed NYSE_BLL_2018 with 8466 tokens.
# Processed NYSE_TEL_2018 with 11612 tokens.
# Processed NASDAQ_AMAT_2015 with 3732 tokens.
# Processed NYSE_XRX_2018 with 16547 tokens.
# Processed NYSE_CHD_2015 with 3023 tokens.
# Processed NYSE_WMT_2010 with 9696 tokens.
# Processed NYSE_D_2019 with 50468 tokens.
# Processed NYSE_CCL_2019 with 34022 tokens.
# Processed NYSE_WMT_2016 with 33623 tokens.
# Processed NASDAQ_CREE_2018 with 7916 tokens.
# Processed NASDAQ_TXN_2013 with 4562 tokens.
# Processed NYSE_IQV_2019 with 5382 tokens.
# Processed NASDAQ_IOSP_2006 with 1547 tokens.
# Processed NYSE_A_2018 with 10589 tokens.
# Processed NYSE_JEC_2014 with 13350 tokens.
# Processed NYSE_CHD_2019 with 12282 tokens.
# Processed NYSE_KRA_2017 with 6763 tokens.
# Processed NYSE_H_2019 with 1739 tokens.
# Processed NYSE_FDX_2009 with 4340 tokens.
# Processed NASDAQ_MDLZ_2015 with 11781 tokens.
# Processed NASDAQ_MSFT_2003 with 6152 tokens.
# Processed NASDAQ_AMAT_2018 with 9510 tokens.
# Processed NYSE_SYY_2014 with 597 tokens.
# Processed NYSE_D_2018 with 37446 tokens.
# Processed NYSE_TNC_2013 with 4701 tokens.
# Processed NYSE_BLL_2014 with 7627 tokens.
# Processed NYSE_CVX_2011 with 11300 tokens.
# Processed NASDAQ_TSLA_2018 with 6244 tokens.
# Processed NYSE_BLL_2011 with 9378 tokens.
# Processed NASDAQ_CTXS_2019 with 6437 tokens.
# Processed NYSE_CCL_2010 with 23779 tokens.
# Processed NYSE_BMI_2017 with 1969 tokens.
# Processed NYSE_ECL_2013 with 6296 tokens.
# Processed NYSE_LII_2017 with 2135 tokens.
# Processed NYSE_NSC_2010 with 15782 tokens.
# Processed NYSE_MAS_2016 with 5372 tokens.
# Processed NYSE_ACN_2016 with 14998 tokens.
# Processed NYSE_NOC_2015 with 12693 tokens.
# Processed NASDAQ_INFN_2019 with 8629 tokens.
# Processed NYSE_UNM_2011 with 4548 tokens.
# Processed NYSE_JNJ_2019 with 2356 tokens.
# Processed NYSE_VAR_2019 with 4257 tokens.
# Processed NASDAQ_CSCO_2019 with 51231 tokens.
# Processed NYSE_CVX_2019 with 11090 tokens.
# Processed NYSE_WM_2012 with 508 tokens.
# Processed NASDAQ_IOSP_2019 with 13704 tokens.
# Processed NYSE_VAR_2015 with 7638 tokens.
# Processed NASDAQ_STX_2018 with 14962 tokens.
# Processed NYSE_ACN_2014 with 15222 tokens.
# Processed NYSE_ORCL_2016 with 12904 tokens.
# Processed NYSE_KMB_2019 with 7637 tokens.
# Processed NYSE_WMT_2005 with 5504 tokens.
# Processed NYSE_TSN_2012 with 3196 tokens.
# Processed NASDAQ_ITRI_2019 with 5750 tokens.
# Processed NYSE_JBL_2014 with 3056 tokens.
# Processed NYSE_MOS_2013 with 2828 tokens.
# Processed NYSE_KMB_2005 with 18961 tokens.
# Processed NYSE_LLY_2014 with 28113 tokens.
# Processed NYSE_CPS_2018 with 16361 tokens.
# Processed NYSE_TFX_2019 with 3554 tokens.
# Processed NYSE_JLL_2017 with 16002 tokens.
# Processed NASDAQ_CLNE_2017 with 7108 tokens.
# Processed NASDAQ_STX_2014 with 8592 tokens.
# Processed NYSE_TMO_2016 with 3559 tokens.
# Processed NYSE_AQUA_2019 with 5147 tokens.
# Processed NASDAQ_TXN_2019 with 19469 tokens.
# Processed NYSE_NSC_2016 with 14606 tokens.
# Processed NYSE_APA_2014 with 4183 tokens.
# Processed NYSE_WM_2018 with 1599 tokens.
# Processed NYSE_CMI_2009 with 22548 tokens.
# Processed NYSE_A_2007 with 10580 tokens.
# Processed NYSE_GS_2015 with 3604 tokens.
# Processed NYSE_CVX_2006 with 13211 tokens.
# Processed NYSE_LMT_2016 with 13880 tokens.
# Processed NYSE_NOC_2013 with 12645 tokens.
# Processed NYSE_LXK_2019 with 25373 tokens.
# Processed NYSE_IP_2019 with 21697 tokens.
# Processed NYSE_WFC_2019 with 1907 tokens.
# Processed NYSE_GS_2012 with 1841 tokens.
# Processed NYSE_HUM_2013 with 9527 tokens.
# Processed NASDAQ_INTC_2011 with 49081 tokens.
# Processed NYSE_A_2003 with 15959 tokens.
# Processed NYSE_TSN_2013 with 23800 tokens.
# Processed NASDAQ_FITB_2018 with 12855 tokens.
# Processed NASDAQ_MDLZ_2013 with 6448 tokens.
# Processed NYSE_NOV_2018 with 7095 tokens.
# Processed NYSE_ECL_2007 with 5762 tokens.
# Processed NYSE_MPC_2011 with 8482 tokens.
# Processed NYSE_BDX_2013 with 13478 tokens.
# Processed NASDAQ_MSFT_2006 with 13829 tokens.
# Processed NYSE_T_2006 with 5165 tokens.
# Processed NYSE_POR_2017 with 951 tokens.
# Processed NASDAQ_IOSP_2012 with 6286 tokens.
# Processed NYSE_CL_2013 with 10036 tokens.
# Processed NYSE_OSK_2014 with 6038 tokens.
# Processed NASDAQ_TPIC_2019 with 5657 tokens.
# Processed NYSE_WLK_2019 with 4433 tokens.
# Processed NYSE_AGN_2017 with 7885 tokens.
# Processed NASDAQ_CSCO_2016 with 47364 tokens.
# Processed NYSE_CAH_2018 with 6580 tokens.
# Processed NYSE_EBS_2019 with 1785 tokens.
# Processed NYSE_TT_2019 with 22123 tokens.
# Processed NYSE_ALB_2019 with 14326 tokens.
# Processed NYSE_BMI_2019 with 3479 tokens.
# Processed NYSE_AWK_2018 with 20281 tokens.
# Processed NASDAQ_SPWR_2014 with 479 tokens.
# Processed NYSE_DCI_2018 with 3517 tokens.
# Processed NYSE_ALB_2013 with 19285 tokens.
# Processed NYSE_TSE_2017 with 5943 tokens.
# Processed NYSE_ALB_2012 with 18231 tokens.
# Processed NYSE_ECL_2004 with 2726 tokens.
# Processed NYSE_CNX_2018 with 9811 tokens.
# Processed NYSE_HIG_2015 with 1228 tokens.
# Processed NASDAQ_STX_2012 with 9574 tokens.
# Processed NASDAQ_GNTX_2017 with 3595 tokens.
# Processed NYSE_JLL_2019 with 27387 tokens.
# Processed NYSE_CCL_2016 with 27436 tokens.
# Processed NYSE_A_2013 with 12891 tokens.
# Processed NASDAQ_MSFT_2009 with 3080 tokens.
# Processed NYSE_HUM_2017 with 15924 tokens.
# Processed NYSE_BWA_2019 with 5566 tokens.
# Processed NYSE_LXK_2018 with 24150 tokens.
# Processed NASDAQ_MDLZ_2018 with 9120 tokens.
# Processed NYSE_ORCL_2012 with 19665 tokens.
# Processed NYSE_SLB_2018 with 18591 tokens.
# Processed NASDAQ_KLAC_2018 with 4683 tokens.
# Processed NYSE_VAR_2014 with 8824 tokens.
# Processed NYSE_JEC_2019 with 4929 tokens.
# Processed NYSE_COF_2018 with 20747 tokens.
# Processed NYSE_MMM_2017 with 34981 tokens.
# Processed NYSE_SYY_2011 with 1303 tokens.
# Processed NYSE_TSN_2018 with 25330 tokens.
# Processed NYSE_VMW_2017 with 3125 tokens.
# Processed NYSE_BA_2016 with 10227 tokens.
# Processed NYSE_B_2017 with 6223 tokens.
# Processed NYSE_WAB_2018 with 4563 tokens.
# Processed NYSE_IBM_2011 with 26751 tokens.
# Processed NASDAQ_AAPL_2015 with 9375 tokens.
# Processed NYSE_JEC_2013 with 17651 tokens.
# Processed NYSE_LXK_2012 with 26539 tokens.
# Processed NYSE_GS_2010 with 6577 tokens.
# Processed NASDAQ_CWST_2012 with 5280 tokens.
# Processed NYSE_AES_2016 with 12894 tokens.
# Processed NYSE_CF_2014 with 2782 tokens.
# Processed NYSE_MS_2010 with 8819 tokens.
# Processed NYSE_CPS_2016 with 9993 tokens.
# Processed NASDAQ_SBUX_2002 with 7800 tokens.
# Processed NYSE_TDC_2013 with 17314 tokens.
# Processed NASDAQ_SBUX_2009 with 3827 tokens.
# Processed NYSE_AROC_2019 with 6224 tokens.
# Processed NYSE_CAT_2019 with 6900 tokens.
# Processed NYSE_CLB_2017 with 12856 tokens.
# Processed NYSE_GS_2016 with 3843 tokens.
# Processed NYSE_MPC_2018 with 11617 tokens.
# Processed NASDAQ_FSLR_2019 with 7353 tokens.
# Processed NYSE_KEYS_2019 with 8775 tokens.
# Processed NASDAQ_CWST_2014 with 9768 tokens.
# Processed NYSE_ATR_2016 with 14728 tokens.
# Processed NYSE_TDC_2017 with 14434 tokens.
# Processed NASDAQ_CCRN_2019 with 6323 tokens.
# Processed NYSE_CMC_2016 with 8112 tokens.
# Processed NYSE_KMB_2007 with 15886 tokens.
# Processed NASDAQ_MSFT_2013 with 15801 tokens.
# Processed NYSE_BA_2014 with 12119 tokens.
# Processed NYSE_CAT_2011 with 13091 tokens.
# Processed NYSE_OC_2016 with 41360 tokens.
# Processed NYSE_X_2019 with 13295 tokens.
# Processed NYSE_BAX_2015 with 15490 tokens.
# Processed NYSE_A_2008 with 11485 tokens.
# Processed NYSE_MDT_2014 with 18539 tokens.
# Processed NASDAQ_IOSP_2015 with 7242 tokens.
# Processed NYSE_PRU_2013 with 10624 tokens.
# Processed NYSE_DUK_2007 with 12505 tokens.
# Processed NYSE_VMI_2017 with 1211 tokens.
# Processed NYSE_F_2018 with 30189 tokens.
# Processed NYSE_CVX_2002 with 20130 tokens.
# Processed NASDAQ_ADBE_2016 with 1420 tokens.
# Processed NYSE_CF_2015 with 4201 tokens.
# Processed NYSE_LXK_2008 with 15961 tokens.
# Processed NYSE_CB_2017 with 90216 tokens.
# Processed NYSE_UNM_2013 with 4769 tokens.
# Processed NYSE_PK_2018 with 3403 tokens.
# Processed NYSE_PBI_2017 with 12013 tokens.
# Processed NYSE_BDX_2018 with 14941 tokens.
# Processed NYSE_BAX_2010 with 54900 tokens.
# Processed NYSE_LXK_2009 with 17451 tokens.
# Processed NASDAQ_AMZN_2019 with 8593 tokens.
# Processed NYSE_JNJ_2011 with 28800 tokens.
# Processed NYSE_RAD_2019 with 6593 tokens.
# Processed NYSE_KRA_2019 with 7852 tokens.
# Processed NASDAQ_HOLX_2019 with 7388 tokens.
# Processed NASDAQ_COMM_2014 with 2774 tokens.
# Processed NYSE_KBR_2018 with 9250 tokens.
# Processed NYSE_A_2010 with 5509 tokens.
# Processed NYSE_TDC_2019 with 14054 tokens.
# Processed NYSE_CRM_2018 with 6889 tokens.
# Processed NASDAQ_MYL_2018 with 17193 tokens.
# Processed NYSE_CVX_2010 with 9767 tokens.
# Processed NYSE_CMI_2013 with 31317 tokens.
# Processed NYSE_GS_2008 with 6203 tokens.
# Processed NYSE_BKR_2018 with 8944 tokens.
# Processed NYSE_TT_2014 with 18754 tokens.
# Processed NASDAQ_REGI_2019 with 5100 tokens.
# Processed NYSE_IQV_2018 with 3775 tokens.
# Processed NYSE_CNX_2016 with 9886 tokens.
# Processed NYSE_NOC_2016 with 12678 tokens.
# Processed NASDAQ_NVDA_2017 with 13233 tokens.
# Processed NYSE_NOC_2012 with 11169 tokens.
# Processed NYSE_JNJ_2014 with 37595 tokens.
# Processed NYSE_ALB_2014 with 21004 tokens.
# Processed NYSE_WFC_2017 with 11073 tokens.
# Processed NYSE_MMM_2018 with 41347 tokens.
# Processed NYSE_VZ_2014 with 18531 tokens.
# Processed NYSE_NSC_2013 with 27042 tokens.
# Processed NYSE_ASH_2019 with 9593 tokens.
# Processed NYSE_PG_2000 with 13450 tokens.
# Processed NASDAQ_CSIQ_2019 with 14062 tokens.
# Processed NASDAQ_NVDA_2018 with 14085 tokens.
# Processed NYSE_NEM_2017 with 43598 tokens.
# Processed NYSE_BTU_2015 with 14454 tokens.
# Processed NYSE_FMC_2016 with 7918 tokens.
# Processed NYSE_PVH_2014 with 11207 tokens.
# Processed NYSE_IBM_2016 with 29991 tokens.
# Processed NYSE_BBY_2016 with 8658 tokens.
# Processed NYSE_ITW_2019 with 815 tokens.
# Processed NYSE_JEC_2016 with 15317 tokens.
# Processed NASDAQ_COMM_2018 with 8901 tokens.
# Processed NYSE_LLY_2016 with 12647 tokens.
# Processed NASDAQ_NXPI_2018 with 20956 tokens.
# Processed NYSE_BDX_2015 with 3840 tokens.
# Processed NASDAQ_UNFI_2013 with 3025 tokens.
# Processed NYSE_AVY_2019 with 52571 tokens.
# Processed NYSE_ANET_2018 with 5783 tokens.
# Processed NYSE_CRM_2017 with 3754 tokens.
# Processed NASDAQ_GILD_2018 with 8811 tokens.
# Processed NASDAQ_BIIB_2015 with 16644 tokens.
# Processed NYSE_MS_2016 with 5968 tokens.
# Processed NYSE_BKR_2017 with 7813 tokens.
# Processed NASDAQ_UNFI_2019 with 4845 tokens.
# Processed NASDAQ_INTC_2009 with 36564 tokens.
# Processed NYSE_AGN_2018 with 8935 tokens.
# Processed NASDAQ_ADBE_2017 with 1769 tokens.
# Processed NYSE_T_2018 with 5378 tokens.
# Processed NASDAQ_STX_2007 with 8920 tokens.
# Processed NYSE_RSG_2018 with 6739 tokens.
# Processed NYSE_WHR_2018 with 10092 tokens.
# Processed NYSE_UNM_2009 with 4284 tokens.
# Processed NYSE_VZ_2017 with 7003 tokens.
# Processed NYSE_IBM_2019 with 15095 tokens.
# Processed NYSE_PBI_2009 with 6982 tokens.
# Processed NYSE_RMD_2019 with 9297 tokens.
# Processed NYSE_JEC_2017 with 12574 tokens.
# Processed NYSE_IBM_2005 with 15357 tokens.
# Processed NYSE_WHR_2017 with 8419 tokens.
# Processed NYSE_OMC_2019 with 10665 tokens.
# Processed NYSE_NBL_2017 with 14825 tokens.
# Processed NYSE_CCL_2013 with 29043 tokens.
# Processed NASDAQ_KHC_2019 with 17875 tokens.
# Processed NASDAQ_CWST_2009 with 6445 tokens.
# Processed NYSE_ADM_2014 with 5944 tokens.
# Processed NYSE_TTC_2019 with 5258 tokens.
# Processed NASDAQ_AMGN_2016 with 4620 tokens.
# Processed NYSE_B_2018 with 4709 tokens.
# Processed NASDAQ_TXN_2016 with 5064 tokens.
# Processed NYSE_BTU_2013 with 17779 tokens.
# Processed NASDAQ_AZPN_2019 with 3067 tokens.
# Processed NASDAQ_SNBR_2019 with 7155 tokens.
# Processed NYSE_PHM_2016 with 3799 tokens.
# Processed NYSE_VZ_2009 with 9883 tokens.
# Processed NASDAQ_SBUX_2013 with 6000 tokens.
# Processed NYSE_BTU_2011 with 16112 tokens.
# Processed NYSE_HIG_2017 with 4808 tokens.
# Processed NYSE_NBL_2011 with 10846 tokens.
# Processed NYSE_GS_2011 with 7699 tokens.
# Processed NASDAQ_FITB_2017 with 7232 tokens.
# Processed NYSE_ALB_2018 with 12470 tokens.
# Processed NASDAQ_ITRI_2016 with 2799 tokens.
# Processed NYSE_OC_2015 with 33831 tokens.
# Processed NYSE_T_2017 with 4546 tokens.
# Processed NYSE_MMM_2011 with 22337 tokens.
# Processed NYSE_ALB_2008 with 21551 tokens.
# Processed NYSE_CMI_2016 with 14517 tokens.
# Processed NYSE_TT_2013 with 17448 tokens.
# Processed NASDAQ_SBUX_2006 with 23643 tokens.
# Processed NYSE_NBL_2019 with 15971 tokens.
# Processed NASDAQ_WWD_2017 with 4457 tokens.
# Processed NYSE_MHK_2018 with 3707 tokens.
# Processed NASDAQ_GILD_2017 with 13403 tokens.
# Processed NYSE_UNM_2010 with 4912 tokens.
# Processed NYSE_NSC_2019 with 10660 tokens.
# Processed NYSE_PBI_2016 with 11161 tokens.
# Processed NASDAQ_GILD_2016 with 8807 tokens.
# Processed NYSE_RSG_2016 with 6136 tokens.
# Processed NYSE_VZ_2008 with 9180 tokens.
# Processed NYSE_CVX_2007 with 13787 tokens.
# Processed NYSE_IRM_2013 with 5434 tokens.
# Processed NYSE_PII_2018 with 5890 tokens.
# Processed NYSE_BTU_2014 with 15571 tokens.
# Processed NASDAQ_IOSP_2009 with 2394 tokens.
# Processed NYSE_CMI_2018 with 13727 tokens.
# Processed NYSE_MS_2009 with 6144 tokens.
# Processed NASDAQ_INFN_2017 with 6453 tokens.
# Processed NYSE_WHR_2014 with 5877 tokens.
# Processed NYSE_JEC_2012 with 14684 tokens.
# Processed NASDAQ_AAPL_2017 with 13634 tokens.
# Processed NYSE_IP_2018 with 1439 tokens.
# Processed NYSE_ORA_2018 with 24894 tokens.
# Processed NASDAQ_ADBE_2014 with 1411 tokens.
# Processed NASDAQ_CSCO_2006 with 17877 tokens.
# Processed NYSE_WTS_2018 with 4393 tokens.
# Processed NYSE_ITW_2014 with 6868 tokens.
# Processed NYSE_TT_2017 with 12056 tokens.
# Processed NYSE_WHR_2019 with 13003 tokens.
# Processed NYSE_BA_2017 with 7805 tokens.
# Processed NASDAQ_ADSK_2018 with 2556 tokens.
# Processed NYSE_VZ_2012 with 7404 tokens.
# Processed NYSE_DGX_2015 with 8261 tokens.
# Processed NYSE_HIG_2019 with 5975 tokens.
# Processed NYSE_DD_2018 with 16851 tokens.
# Processed NASDAQ_SNPS_2019 with 3409 tokens.
# Processed NYSE_PVH_2016 with 10879 tokens.
# Processed NYSE_AES_2012 with 12547 tokens.
# Processed NYSE_DOW_2017 with 28179 tokens.
# Processed NYSE_BTU_2019 with 9204 tokens.
# Processed NASDAQ_CSCO_2008 with 38533 tokens.
# Processed NYSE_TT_2007 with 10248 tokens.
# Processed NYSE_DAL_2016 with 20475 tokens.
# Processed NYSE_AOS_2018 with 3920 tokens.
# Processed NYSE_KEYS_2016 with 28765 tokens.
# Processed NYSE_FTV_2019 with 6504 tokens.
# Processed NYSE_MA_2019 with 19712 tokens.
# Processed NYSE_EMN_2019 with 14412 tokens.
# Processed NYSE_XRX_2019 with 19017 tokens.
# Processed NYSE_GPK_2017 with 8647 tokens.
# Processed NYSE_AWK_2016 with 13499 tokens.
# Processed NASDAQ_VRTX_2018 with 2269 tokens.
# Processed NYSE_DAL_2018 with 20855 tokens.
# Processed NYSE_NI_2016 with 1943 tokens.
# Processed NYSE_DAL_2017 with 19325 tokens.
# Processed NYSE_WHR_2013 with 4532 tokens.
# Processed NYSE_SCS_2014 with 5974 tokens.
# Processed NYSE_BAX_2017 with 17720 tokens.
# Processed NYSE_CRM_2016 with 2707 tokens.
# Processed NASDAQ_CSCO_2015 with 42363 tokens.
# Processed NASDAQ_AMAT_2013 with 3075 tokens.
# Processed NYSE_OSK_2019 with 10575 tokens.
# Processed NASDAQ_SBUX_2005 with 18802 tokens.
# Processed NYSE_TT_2012 with 13891 tokens.
# Processed NYSE_NOC_2010 with 11451 tokens.
# Processed NYSE_TSN_2016 with 13148 tokens.
# Processed NYSE_OSK_2016 with 7579 tokens.
# Processed NYSE_UNM_2017 with 2430 tokens.
# Processed NYSE_AXL_2018 with 2755 tokens.
# Saved 1486 processed documents.

# %%
len(valid_filenames)
# Out:
# 1486

# %% [markdown]
# # TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd
import numpy as np
import joblib  # 用來儲存 vectorizer

# %%
# 1. 載入處理後資料
df = pd.read_csv("../output_dataset/csr_text_processed_v0_preprocessed.csv")

# 2. 取出 clean_text 欄位
texts = df["clean_text"].fillna("")

# 3. 建立 TF-IDF vectorizer（你可依需求調整參數）
vectorizer = TfidfVectorizer(
    # max_features=10000,         # 保留所有特徵，後續再做選擇
    ngram_range=(1, 2),         # 一元與二元詞（unigram + bigram）
    min_df=15,                   # 10~30	出現在 0.7%~2% 文檔中，1500 篇文章的理想區間
    max_df=0.8,                 # 0.7–0.9	移除超過 70~90% 文檔都出現的詞彙， 1500 篇推薦範圍，可濾除常見無效語彙
    stop_words="english"        # 雙重保險停用詞（可與 spaCy 停用詞互補）
)

# 4. 向量化
X_tfidf = vectorizer.fit_transform(texts)  # 結果為 sparse matrix，shape = (n_samples, n_features)

# 5. 輸出 TF-IDF 基本統計
print(f"TF-IDF shape: {X_tfidf.shape}")
non_zero = X_tfidf.count_nonzero()
density = non_zero / (X_tfidf.shape[0] * X_tfidf.shape[1])
print(f"Non-zero entries: {non_zero}")
print(f"Matrix density: {density:.6f}")
# 檢查是否有全為 0 的向量（稀疏過頭）
empty_docs = (X_tfidf.sum(axis=1) == 0).A1  # 轉成 1D 陣列
print(f"Empty TF-IDF vectors: {np.sum(empty_docs)} / {X_tfidf.shape[0]}")

# 6. 儲存 TF-IDF 矩陣（可選）
from scipy import sparse
sparse.save_npz("../output_dataset/csr_text_processed_tf_idf.npz", X_tfidf)

# 7. 儲存 TF-IDF vectorizer 物件
joblib.dump(vectorizer, "../output_dataset/csr_text_processed_tf_idf.pkl")

# 8. 儲存所有 TF-IDF 特徵名稱（for feature selection、可視化等）
feature_names = vectorizer.get_feature_names_out()
pd.Series(feature_names).to_csv("../output_dataset/csr_text_tfidf_feature_names.csv", index=False)

print("✅ TF-IDF 向量化與儲存完成！")
# Out:
# TF-IDF shape: (1486, 140069)
# Non-zero entries: 8109075
# Matrix density: 0.038959
# Empty TF-IDF vectors: 0 / 1486
# ✅ TF-IDF 向量化與儲存完成！

# %% [markdown]
# # Mutual Information

# %%
import pandas as pd
import numpy as np
from scipy import sparse
from sklearn.feature_selection import mutual_info_regression
from sklearn.feature_selection import SelectKBest
import joblib

# %% [markdown]
# ## Select top k

# %%
def select_top_k_features_by_target(X_tfidf, y, feature_names, target_name, output_dir, k=1000):
    """
    根據指定的 y，進行 mutual information 特徵選擇，並儲存篩選後的矩陣與詞彙名稱。
    
    Args:
        X_tfidf: TF-IDF 特徵矩陣 (scipy.sparse.csr_matrix)
        y: 對應目標變數的一維 array
        feature_names: TF-IDF 對應詞彙陣列
        target_name: 任務名稱（如 "patent"）
        output_dir: 輸出資料夾
        k: 要選出的 top-k 特徵數
    """
    print("=" * 60)
    print(f"🔍 Selecting top {k} features for target: '{target_name}'")
    
    # 安全限制 k 不超過現有特徵數
    k = min(k, X_tfidf.shape[1])

    # 計算 MI 分數
    X_dense = X_tfidf.toarray()
    mi_scores = mutual_info_regression(X_dense, y, discrete_features=False)

    # 取得 top-k 特徵索引與詞彙
    top_k_idx = np.argsort(mi_scores)[-k:]
    X_selected = X_tfidf[:, top_k_idx]
    selected_features = feature_names[top_k_idx]

    # 儲存 TF-IDF 子矩陣
    sparse.save_npz(os.path.join(output_dir, f"tfidf_top{k}_{target_name}.npz"), X_selected)

    # 儲存詞彙名稱
    pd.Series(selected_features).to_csv(
        os.path.join(output_dir, f"tfidf_top{k}_{target_name}_features.csv"), index=False
    )

    # 儲存全部詞彙與對應 MI 分數（可用於可視化）
    mi_df = pd.DataFrame({
        "feature": feature_names,
        "mi_score": mi_scores
    }).sort_values(by="mi_score", ascending=False)
    mi_df.to_csv(os.path.join(output_dir, f"mi_scores_{target_name}.csv"), index=False)

    print(f"✅ Done! Saved TF-IDF matrix and feature list for '{target_name}' with k={k}")
    print("=" * 60 + "\n")

# %% [markdown]
# ## Load file

# %%
# 1. 載入資料
X_tfidf = sparse.load_npz("../output_dataset/csr_text_processed_tf_idf.npz")
df = pd.read_csv("../output_dataset/csr_text_processed_v0_preprocessed.csv")
vectorizer = joblib.load("../output_dataset/csr_text_processed_tf_idf.pkl")
feature_names = vectorizer.get_feature_names_out()
output_dir = "../output_dataset"

# %%
print(f"TF-IDF shape: {X_tfidf.shape}")
# Out:
# TF-IDF shape: (1486, 140069)

# %% [markdown]
# ## Process

# %%
# 2. 執行不同 k 值的特徵選擇（對兩個 y）
for k in [1000, 2000, 3000, 5000]:
    # patent_count
    select_top_k_features_by_target(
        X_tfidf=X_tfidf,
        y=df["patent_count"].values,
        feature_names=feature_names,
        target_name=f"count_k{k}",
        output_dir=output_dir,
        k=k
    )

    # citation_count
    select_top_k_features_by_target(
        X_tfidf=X_tfidf,
        y=df["citation_count"].values,
        feature_names=feature_names,
        target_name=f"citation_k{k}",
        output_dir=output_dir,
        k=k
    )
# Out:
# ============================================================
# 🔍 Selecting top 1000 features for target: 'count_k1000'
