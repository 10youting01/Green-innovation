# %%
import json
import re
import os
import string
import ftfy
import numpy as np
import language_tool_python

# %%
tool = language_tool_python.LanguageTool('en-US')

# %%
def preprocess_text(json_path, output_path, tool):
    try:
        with open(json_path, 'r', encoding='utf-8') as f:
            data = json.load(f)

        # 依據頁碼分類文字
        page_texts = {}
        for item in data:
            page = item.get("page")
            text = item.get("all_text", "").strip()

            if page is not None and text:
                # 先用 ftfy 修正亂碼
                fixed_text = ftfy.fix_text(text)
                if page not in page_texts:
                    page_texts[page] = []
                page_texts[page].append(fixed_text)

        # 將每頁的文字串接並先用 ftfy 修正，再用 tool.correct 矯正
        processed_texts = {
            str(page): tool.correct(ftfy.fix_text(" ".join(texts)))
            for page, texts in page_texts.items()
        }

        # 存成新的 JSON 檔案
        with open(output_path, 'w', encoding='utf-8') as f:
            json.dump(processed_texts, f, ensure_ascii=False, indent=4)

        return f"Processed text saved to {output_path}"

    except FileNotFoundError:
        return "Error: File not found."
    except json.JSONDecodeError:
        return "Error: Invalid JSON format."

# %%
def process_all_nasdaq(base_path, tool):
    """ 遍歷 NASDAQ 目錄，對每個資料夾內的 dense_regions.json 進行改名並處理 """
    for folder_name in os.listdir(base_path):
        folder_path = os.path.join(base_path, folder_name)

        if os.path.isdir(folder_path):  # 確保是資料夾
            old_json_path = os.path.join(folder_path, "dense_regions.json")
            new_json_path = os.path.join(folder_path, f"{folder_name}_v0_extract_text.json")
            output_json_path = os.path.join(folder_path, f"{folder_name}_v1_preprocessed_tool.json")

            # 檢查是否已處理過
            if os.path.exists(output_json_path):
                print(f"Skipping {folder_name}, already processed.")
                continue

            if os.path.exists(old_json_path):
                # 重新命名 dense_regions.json
                os.rename(old_json_path, new_json_path)

                # 執行處理函數
                preprocess_text(new_json_path, output_json_path, tool)

                print(f"Processed: {folder_name}")

# %%
nasdaq_base_path = os.path.abspath("/home/francia/research_hub/csr_project/CSR_report_processed_v4/CSR_report_new_collect")
process_all_nasdaq(nasdaq_base_path, tool)
# Out:
# Skipping NYSE_PFS_2019, already processed.
# Skipping NYSE_HRL_2019, already processed.
# Skipping NYSE_WM_2021, already processed.
# Skipping NYSE_VEDL_2016, already processed.
# Skipping NYSE_JWN_2021, already processed.
# Skipping NYSE_CHK_2017, already processed.
# Skipping NYSE_BHP_2005, already processed.
# Skipping NYSE_DELL_2008, already processed.
# Skipping NYSE_TMO_2014, already processed.
# Skipping NYSE_AA_2019, already processed.
# Skipping NYSE_JEC_2010, already processed.
# Skipping NYSE_FLR_2011, already processed.
# Skipping NYSE_GIS_2011, already processed.
# Skipping NYSE_RMD_2012, already processed.
# Skipping NYSE_VC_2018, already processed.
# Skipping NYSE_INGR_2013, already processed.
# Skipping NYSE_SERV_2019, already processed.
# Skipping NYSE_AEE_2020, already processed.
# Skipping NYSE_KNL_2006, already processed.
# Skipping NYSE_NI_2016, already processed.
# Skipping NYSE_WMB_2021, already processed.
# Skipping NYSE_URI_2014, already processed.
# Skipping NYSE_CAJ_2003, already processed.
# Skipping NYSE_RCI_2019, already processed.
# Skipping NYSE_ALB_2021, already processed.
# Skipping NYSE_UPS_2004, already processed.
# Skipping NYSE_KO_2018, already processed.
# Skipping NYSE_ADM_2015, already processed.
# Skipping NYSE_YUMC_2019, already processed.
# Skipping NYSE_DCI_2017, already processed.
# Skipping NYSE_CMP_2018, already processed.
# Skipping NYSE_UPS_2009, already processed.
# Skipping NYSE_UNM_2011, already processed.
# Skipping NYSE_GS_2018, already processed.
# Skipping NYSE_KEYS_2019, already processed.
# Skipping NYSE_PRU_2016, already processed.
# Skipping NYSE_VST_2020, already processed.
# Skipping NYSE_LLY_2019, already processed.
# Skipping NYSE_KSS_2018, already processed.
# Skipping NYSE_ACI_2020, already processed.
# Skipping NYSE_MTX_2018, already processed.
# Skipping NYSE_RBC_2019, already processed.
# Skipping NYSE_SPXC_2018, already processed.
# Skipping NYSE_GPS_2014, already processed.
# Skipping NYSE_KRC_2015, already processed.
# Skipping NYSE_BKI_2019, already processed.
# Skipping NYSE_DELL_2011, already processed.
# Skipping NYSE_ELAN_2020, already processed.
# Skipping NYSE_ENLC_2018, already processed.
# Skipping NYSE_DAL_2016, already processed.
# Skipping NYSE_RHP_2020, already processed.
# Skipping NYSE_IBM_2019, already processed.
# Skipping NYSE_MMS_2021, already processed.
# Skipping NYSE_BAX_2015, already processed.
# Skipping NYSE_SYF_2019, already processed.
# Skipping NYSE_PCG_2009, already processed.
# Skipping NYSE_SUPV_2021, already processed.
# Skipping NYSE_CLS_2010, already processed.
# Skipping NYSE_WSM_2014, already processed.
# Skipping NYSE_TT_2009, already processed.
# Skipping NYSE_ABC_2020, already processed.
# Skipping NYSE_MCK_2020, already processed.
# Skipping NYSE_JEC_2019, already processed.
# Skipping NYSE_GTI_2019, already processed.
# Skipping NYSE_DUK_2014, already processed.
# Skipping NYSE_HES_2016, already processed.
# Skipping NYSE_INFY_2015, already processed.
# Skipping NYSE_EOG_2021, already processed.
# Skipping NYSE_SLM_2019, already processed.
# Skipping NYSE_HOG_2016, already processed.
# Skipping NYSE_NRG_2014, already processed.
# Skipping NYSE_KR_2018, already processed.
# Skipping NYSE_IAG_2008, already processed.
# Skipping NYSE_SNE_2004, already processed.
# Skipping NYSE_KNL_2011, already processed.
# Skipping NYSE_BCE_2020, already processed.
# Skipping NYSE_PK_2020, already processed.
# Skipping NYSE_HY_2019, already processed.
# Skipping NYSE_LXK_2009, already processed.
# Skipping NYSE_CTB_2014, already processed.
# Skipping NYSE_SON_2019, already processed.
# Skipping NYSE_PRU_2020, already processed.
# Skipping NYSE_JNJ_2017, already processed.
# Skipping NYSE_HRL_2008, already processed.
# Skipping NYSE_COLD_2021, already processed.
# Skipping NYSE_DTE_2014, already processed.
# Skipping NYSE_A_2015, already processed.
# Skipping NYSE_SXC_2019, already processed.
# Skipping NYSE_T_2013, already processed.
# Skipping NYSE_KMX_2019, already processed.
# Skipping NYSE_BXP_2021, already processed.
# Skipping NYSE_ABT_2013, already processed.
# Skipping NYSE_RELX_2010, already processed.
# Skipping NYSE_STZ_2017, already processed.
# Skipping NYSE_OC_2013, already processed.
# Skipping NYSE_SWK_2020, already processed.
# Skipping NYSE_JBGS_2022, already processed.
# Skipping NYSE_GVA_2021, already processed.
# Skipping NYSE_NEM_2020, already processed.
# Skipping NYSE_MLM_2016, already processed.
# Skipping NYSE_TRU_2019, already processed.
# Skipping NYSE_STT_2021, already processed.
# Skipping NYSE_BMY_2020, already processed.
# Skipping NYSE_GS_2019, already processed.
# Skipping NYSE_CWT_2014, already processed.
# Skipping NYSE_EGY_2021, already processed.
# Skipping NYSE_APD_2022, already processed.
# Skipping NYSE_ROK_2021, already processed.
# Skipping NYSE_GM_2019, already processed.
# Skipping NYSE_ATI_2017, already processed.
# Skipping NYSE_VTR_2019, already processed.
# Skipping NYSE_CBRE_2018, already processed.
# Skipping NYSE_ACA_2019, already processed.
# Skipping NYSE_RMD_2019, already processed.
# Skipping NYSE_LMT_2015, already processed.
# Skipping NYSE_CWK_2016, already processed.
# Skipping NYSE_DLR_2020, already processed.
# Skipping NYSE_FMX_2017, already processed.
# Skipping NYSE_MRO_2005, already processed.
# Skipping NYSE_BCE_2018, already processed.
# Skipping NYSE_TVE_2021, already processed.
# Skipping NYSE_MHK_2019, already processed.
# Skipping NYSE_EME_2018, already processed.
# Skipping NYSE_CBZ_2019, already processed.
# Skipping NYSE_VAL_2020, already processed.
# Skipping NYSE_WM_2022, already processed.
# Skipping NYSE_KOP_2015, already processed.
# Skipping NYSE_RDS_2019, already processed.
# Skipping NYSE_BERY_2020, already processed.
# Skipping NYSE_BTU_2013, already processed.
# Skipping NYSE_AU_2019, already processed.
# Skipping NYSE_TT_2010, already processed.
# Skipping NYSE_PNM_2020, already processed.
# Skipping NYSE_RDS_2009, already processed.
# Skipping NYSE_AVT_2020, already processed.
# Skipping NYSE_CPA_2019, already processed.
# Skipping NYSE_BHP_2019, already processed.
# Skipping NYSE_PG_2004, already processed.
# Skipping NYSE_ATR_2021, already processed.
# Skipping NYSE_LLY_2017, already processed.
# Skipping NYSE_KBR_2018, already processed.
# Skipping NYSE_DXC_2018, already processed.
# Skipping NYSE_CAT_2021, already processed.
# Skipping NYSE_ABEV_2016, already processed.
# Skipping NYSE_NBL_2011, already processed.
# Skipping NYSE_DFS_2017, already processed.
# Skipping NYSE_MRK_2018, already processed.
# Skipping NYSE_AVP_2019, already processed.
# Skipping NYSE_EPC_2019, already processed.
# Skipping NYSE_AXP_2021, already processed.
# Skipping NYSE_CMP_2020, already processed.
# Skipping NYSE_EOG_2018, already processed.
# Skipping NYSE_SYF_2020, already processed.
# Skipping NYSE_PBI_2012, already processed.
# Skipping NYSE_MTD_2016, already processed.
# Skipping NYSE_NKE_2009, already processed.
# Skipping NYSE_TMO_2018, already processed.
# Skipping NYSE_SHEL_2021, already processed.
# Skipping NYSE_TPX_2021, already processed.
# Skipping NYSE_RSG_2021, already processed.
# Skipping NYSE_DUK_2010, already processed.
# Skipping NYSE_VEDL_2014, already processed.
# Skipping NYSE_LVS_2020, already processed.
# Skipping NYSE_HDB_2014, already processed.
# Skipping NYSE_IFF_2019, already processed.
# Skipping NYSE_CCL_2010, already processed.
# Skipping NYSE_VALE_2020, already processed.
# Skipping NYSE_HRL_2010, already processed.
# Skipping NYSE_TV_2020, already processed.
# Skipping NYSE_A_2011, already processed.
# Skipping NYSE_GVA_2012, already processed.
# Skipping NYSE_CI_2021, already processed.
# Skipping NYSE_APAM_2021, already processed.
# Skipping NYSE_EL_2015, already processed.
# Skipping NYSE_KOS_2020, already processed.
# Skipping NYSE_SXT_2020, already processed.
# Skipping NYSE_PEP_2015, already processed.
# Skipping NYSE_IFF_2012, already processed.
# Skipping NYSE_THO_2021, already processed.
# Skipping NYSE_COF_2019, already processed.
# Skipping NYSE_CRC_2020, already processed.
# Skipping NYSE_FLR_2010, already processed.
# Skipping NYSE_CXW_2021, already processed.
# Skipping NYSE_KMB_2010, already processed.
# Skipping NYSE_ITW_2012, already processed.
# Skipping NYSE_VC_2022, already processed.
# Skipping NYSE_KB_2015, already processed.
# Skipping NYSE_GM_2017, already processed.
# Skipping NYSE_IFF_2017, already processed.
# Skipping NYSE_ABT_2018, already processed.
# Skipping NYSE_BG_2019, already processed.
# Skipping NYSE_CNP_2022, already processed.
# Skipping NYSE_CVX_2011, already processed.
# Skipping NYSE_ALV_2020, already processed.
# Skipping NYSE_AMT_2019, already processed.
# Skipping NYSE_GPK_2018, already processed.
# Skipping NYSE_DTE_2017, already processed.
# Skipping NYSE_WAB_2021, already processed.
# Skipping NYSE_CVS_2019, already processed.
# Skipping NYSE_DE_2021, already processed.
# Skipping NYSE_HPE_2016, already processed.
# Skipping NYSE_IBM_2017, already processed.
# Skipping NYSE_ALLY_2018, already processed.
# Skipping NYSE_AEP_2017, already processed.
# Skipping NYSE_PPG_2013, already processed.
# Skipping NYSE_TUP_2017, already processed.
# Skipping NYSE_PGRE_2019, already processed.
# Skipping NYSE_BSX_2021, already processed.
# Skipping NYSE_LOW_2003, already processed.
# Skipping NYSE_ATO_2020, already processed.
# Skipping NYSE_NSC_2022, already processed.
# Skipping NYSE_PRO_2020, already processed.
# Skipping NYSE_GT_2021, already processed.
# Skipping NYSE_NSC_2010, already processed.
# Skipping NYSE_CVX_2021, already processed.
# Skipping NYSE_OMC_2016, already processed.
# Skipping NYSE_APO_2018, already processed.
# Skipping NYSE_AEP_2021, already processed.
# Skipping NYSE_RBC_2020, already processed.
# Skipping NYSE_KR_2021, already processed.
# Skipping NYSE_DGX_2015, already processed.
# Skipping NYSE_PBI_2014, already processed.
# Skipping NYSE_AAT_2019, already processed.
# Skipping NYSE_WLK_2018, already processed.
# Skipping NYSE_WFC_2019, already processed.
# Skipping NYSE_PG_2000, already processed.
# Skipping NYSE_BAX_2011, already processed.
# Skipping NYSE_PNW_2021, already processed.
# Skipping NYSE_TUP_2012, already processed.
# Skipping NYSE_GSH_2015, already processed.
# Skipping NYSE_ALV_2015, already processed.
# Skipping NYSE_B_2018, already processed.
# Skipping NYSE_CBRE_2007, already processed.
# Skipping NYSE_HUN_2012, already processed.
# Skipping NYSE_HOG_2019, already processed.
# Skipping NYSE_WHR_2015, already processed.
# Skipping NYSE_WMT_2017, already processed.
# Skipping NYSE_TECK_2003, already processed.
# Skipping NYSE_PDM_2019, already processed.
# Skipping NYSE_CAJ_2013, already processed.
# Skipping NYSE_LMT_2014, already processed.
# Skipping NYSE_DGX_2017, already processed.
# Skipping NYSE_ITW_2020, already processed.
# Skipping NYSE_CNP_2017, already processed.
# Skipping NYSE_XHR_2020, already processed.
# Skipping NYSE_GIL_2005, already processed.
# Skipping NYSE_INGR_2012, already processed.
# Skipping NYSE_ACM_2013, already processed.
# Skipping NYSE_QVCC_2016, already processed.
# Skipping NYSE_NBL_2017, already processed.
# Skipping NYSE_AGN_2017, already processed.
# Skipping NYSE_CFG_2017, already processed.
# Skipping NYSE_CLB_2019, already processed.
# Skipping NYSE_SPP_2017, already processed.
# Skipping NYSE_JBGS_2018, already processed.
# Skipping NYSE_CAJ_2010, already processed.
# Skipping NYSE_ALL_2012, already processed.
# Skipping NYSE_PNC_2021, already processed.
# Skipping NYSE_NGVT_2021, already processed.
# Skipping NYSE_WDAY_2017, already processed.
# Skipping NYSE_ADS_2017, already processed.
# Skipping NYSE_RL_2020, already processed.
# Skipping NYSE_PLD_2018, already processed.
# Skipping NYSE_ES_2019, already processed.
# Skipping NYSE_CI_2020, already processed.
# Skipping NYSE_SPGI_2017, already processed.
# Skipping NYSE_WSM_2012, already processed.
# Skipping NYSE_SQM_2011, already processed.
# Skipping NYSE_MMM_2017, already processed.
# Skipping NYSE_AHH_2020, already processed.
# Skipping NYSE_BKR_2020, already processed.
# Skipping NYSE_CS_2018, already processed.
# Skipping NYSE_HAS_2013, already processed.
# Skipping NYSE_NEE_2020, already processed.
# Skipping NYSE_ATR_2017, already processed.
# Skipping NYSE_LOW_2015, already processed.
# Skipping NYSE_HOG_2010, already processed.
# Skipping NYSE_TEVA_2012, already processed.
# Skipping NYSE_NKE_2013, already processed.
# Skipping NYSE_RF_2016, already processed.
# Skipping NYSE_GSH_2013, already processed.
# Skipping NYSE_DNB_2021, already processed.
# Skipping NYSE_TVE_2019, already processed.
# Skipping NYSE_PRU_2013, already processed.
# Skipping NYSE_ALL_2011, already processed.
# Skipping NYSE_NJR_2017, already processed.
# Skipping NYSE_BSX_2018, already processed.
# Skipping NYSE_TDC_2012, already processed.
# Skipping NYSE_CVS_2008, already processed.
# Skipping NYSE_KMB_2012, already processed.
# Skipping NYSE_TCO_2020, already processed.
# Skipping NYSE_AFL_2019, already processed.
# Skipping NYSE_KR_2016, already processed.
# Skipping NYSE_BK_2020, already processed.
# Skipping NYSE_FCN_2019, already processed.
# Skipping NYSE_GEO_2019, already processed.
# Skipping NYSE_MMM_2011, already processed.
# Skipping NYSE_CHD_2015, already processed.
# Skipping NYSE_PH_2019, already processed.
# Skipping NYSE_CPT_2019, already processed.
# Skipping NYSE_SNE_2006, already processed.
# Skipping NYSE_BHC_2021, already processed.
# Skipping NYSE_RF_2019, already processed.
# Skipping NYSE_PEAK_2020, already processed.
# Skipping NYSE_ED_2013, already processed.
# Skipping NYSE_UPS_2012, already processed.
# Skipping NYSE_CLNY_2019, already processed.
# Skipping NYSE_DRE_2018, already processed.
# Skipping NYSE_RRC_2021, already processed.
# Skipping NYSE_PM_2020, already processed.
# Skipping NYSE_RDS_2015, already processed.
# Skipping NYSE_DIS_2019, already processed.
# Skipping NYSE_NHS_2018, already processed.
# Skipping NYSE_SITC_2016, already processed.
# Skipping NYSE_ZEN_2021, already processed.
# Skipping NYSE_LEA_2019, already processed.
# Skipping NYSE_UFI_2020, already processed.
# Skipping NYSE_ADM_2017, already processed.
# Skipping NYSE_CS_2017, already processed.
# Skipping NYSE_VMC_2020, already processed.
# Skipping NYSE_B_2015, already processed.
# Skipping NYSE_PNC_2015, already processed.
# Skipping NYSE_ELAN_2019, already processed.
# Skipping NYSE_CC_2018, already processed.
# Skipping NYSE_AVYA_2021, already processed.
# Skipping NYSE_MBT_2019, already processed.
# Skipping NYSE_TECK_2002, already processed.
# Skipping NYSE_DELL_2000, already processed.
# Skipping NYSE_TREX_2020, already processed.
# Skipping NYSE_AROC_2019, already processed.
# Skipping NYSE_KBH_2019, already processed.
# Skipping NYSE_TXT_2020, already processed.
# Skipping NYSE_OC_2019, already processed.
# Skipping NYSE_UFS_2021, already processed.
# Skipping NYSE_TI_2001, already processed.
# Skipping NYSE_CTL_2014, already processed.
# Skipping NYSE_TJX_2022, already processed.
# Skipping NYSE_hpq_2016, already processed.
# Skipping NYSE_A_2010, already processed.
# Skipping NYSE_CMA_2016, already processed.
# Skipping NYSE_CB_2020, already processed.
# Skipping NYSE_BHP_2001, already processed.
# Skipping NYSE_XOM_2017, already processed.
# Skipping NYSE_WMT_2019, already processed.
# Skipping NYSE_APD_2019, already processed.
# Skipping NYSE_FUL_2015, already processed.
# Skipping NYSE_UNM_2016, already processed.
# Skipping NYSE_HAS_2015, already processed.
# Skipping NYSE_ALL_2003, already processed.
# Skipping NYSE_PSA_2020, already processed.
# Skipping NYSE_MAN_2018, already processed.
# Skipping NYSE_VNO_2019, already processed.
# Skipping NYSE_SNE_2001, already processed.
# Skipping NYSE_DVN_2021, already processed.
# Skipping NYSE_JEC_2020, already processed.
# Skipping NYSE_CI_2016, already processed.
# Skipping NYSE_ARE_2019, already processed.
# Skipping NYSE_JNJ_2011, already processed.
# Skipping NYSE_BTU_2015, already processed.
# Skipping NYSE_GIL_2006, already processed.
# Skipping NYSE_ARNC_2018, already processed.
# Skipping NYSE_PII_2018, already processed.
# Skipping NYSE_KBH_2010, already processed.
# Skipping NYSE_TJX_2013, already processed.
# Skipping NYSE_BA_2017, already processed.
# Skipping NYSE_NNN_2021, already processed.
# Skipping NYSE_GM_2021, already processed.
# Skipping NYSE_MMM_2013, already processed.
# Skipping NYSE_FLR_2015, already processed.
# Skipping NYSE_AVB_2017, already processed.
# Skipping NYSE_SHG_2018, already processed.
# Skipping NYSE_WRI_2019, already processed.
# Skipping NYSE_CCL_2019, already processed.
# Skipping NYSE_TROX_2012, already processed.
# Skipping NYSE_UNP_2019, already processed.
# Skipping NYSE_ANET_2020, already processed.
# Skipping NYSE_UNVR_2017, already processed.
# Skipping NYSE_BAX_2014, already processed.
# Skipping NYSE_KRC_2018, already processed.
# Skipping NYSE_PCG_2012, already processed.
# Skipping NYSE_CCI_2020, already processed.
# Skipping NYSE_VEDL_2009, already processed.
# Skipping NYSE_AEP_2014, already processed.
# Skipping NYSE_MIC_2018, already processed.
# Skipping NYSE_T_2017, already processed.
# Skipping NYSE_LLY_2011, already processed.
# Skipping NYSE_M_2020, already processed.
# Skipping NYSE_WLK_2017, already processed.
# Skipping NYSE_HPE_2019, already processed.
# Skipping NYSE_BA_2020, already processed.
# Skipping NYSE_ABC_2021, already processed.
# Skipping NYSE_CHK_2013, already processed.
# Skipping NYSE_TRU_2020, already processed.
# Skipping NYSE_MPC_2019, already processed.
# Skipping NYSE_AXP_2017, already processed.
# Skipping NYSE_FLS_2019, already processed.
# Skipping NYSE_LPL_2020, already processed.
# Skipping NYSE_PG_2009, already processed.
# Skipping NYSE_AES_2014, already processed.
# Skipping NYSE_HT_2019, already processed.
# Skipping NYSE_OSK_2014, already processed.
# Skipping NYSE_CL_2013, already processed.
# Skipping NYSE_MKC_2017, already processed.
# Skipping NYSE_BCE_2013, already processed.
# Skipping NYSE_OSK_2021, already processed.
# Skipping NYSE_WSM_2011, already processed.
# Skipping NYSE_DELL_2005, already processed.
# Skipping NYSE_CSTM_2014, already processed.
# Skipping NYSE_VRS_2008, already processed.
# Skipping NYSE_SKT_2020, already processed.
# Skipping NYSE_T_2016, already processed.
# Skipping NYSE_BWA_2018_2019, already processed.
# Skipping NYSE_DAR_2021, already processed.
# Skipping NYSE_MET_2019, already processed.
# Skipping NYSE_RDY_2017, already processed.
# Skipping NYSE_DELL_2012, already processed.
# Skipping NYSE_PII_2015, already processed.
# Skipping NYSE_JHG_2018, already processed.
# Skipping NYSE_SITC_2017, already processed.
# Skipping NYSE_CCL_2011, already processed.
# Skipping NYSE_BK_2012, already processed.
# Skipping NYSE_STM_2012, already processed.
# Skipping NYSE_HPE_2021, already processed.
# Skipping NYSE_WMB_2020, already processed.
# Skipping NYSE_SHG_2020, already processed.
# Skipping NYSE_JNJ_2021, already processed.
# Skipping NYSE_ORA_2018, already processed.
# Skipping NYSE_CNHI_2021, already processed.
# Skipping NYSE_AWR_2019, already processed.
# Skipping NYSE_BAH_2016, already processed.
# Skipping NYSE_ZMH_2019, already processed.
# Skipping NYSE_KBH_2020, already processed.
# Skipping NYSE_APTS_2021, already processed.
# Skipping NYSE_VALE_2007, already processed.
# Skipping NYSE_HES_2014, already processed.
# Skipping NYSE_INFO_2016, already processed.
# Skipping NYSE_ZNH_2018, already processed.
# Skipping NYSE_SCS_2013, already processed.
# Skipping NYSE_SJW_2021, already processed.
# Skipping NYSE_IP_2017, already processed.
# Skipping NYSE_JLL_2016, already processed.
# Skipping NYSE_AM_2020, already processed.
# Skipping NYSE_LND_20140701_20150630, already processed.
# Skipping NYSE_DHR_2016, already processed.
# Skipping NYSE_TREX_2019, already processed.
# Skipping NYSE_SUM_2019, already processed.
# Skipping NYSE_NEM_2016, already processed.
# Skipping NYSE_DNR_2022, already processed.
# Skipping NYSE_URI_2012, already processed.
# Skipping NYSE_SON_2016, already processed.
# Skipping NYSE_JEC_2009, already processed.
# Skipping NYSE_FSP_2018, already processed.
# Skipping NYSE_FMC_2016, already processed.
# Skipping NYSE_GPN_2019, already processed.
# Skipping NYSE_NAV_2019, already processed.
# Skipping NYSE_CPB_2015, already processed.
# Skipping NYSE_UTL_2019, already processed.
# Skipping NYSE_T_2008, already processed.
# Skipping NYSE_INN_2020, already processed.
# Skipping NYSE_ARMK_2020, already processed.
# Skipping NYSE_GIS_2022, already processed.
# Skipping NYSE_KOP_2010, already processed.
# Skipping NYSE_COP_2008, already processed.
# Skipping NYSE_SR_2019, already processed.
# Skipping NYSE_BAH_2021, already processed.
# Skipping NYSE_PBI_2015, already processed.
# Skipping NYSE_ACH_2018, already processed.
# Skipping NYSE_CALM_2020, already processed.
# Skipping NYSE_A_2021, already processed.
# Skipping NYSE_SCS_2014, already processed.
# Skipping NYSE_PGR_2020, already processed.
# Skipping NYSE_PSX_2019, already processed.
# Skipping NYSE_PBR_2014, already processed.
# Skipping NYSE_RELX_2019, already processed.
# Skipping NYSE_MMP_2021, already processed.
# Skipping NYSE_CMI_2014, already processed.
# Skipping NYSE_KIM_2018, already processed.
# Skipping NYSE_VRS_2015, already processed.
# Skipping NYSE_JWN_2019, already processed.
# Skipping NYSE_NVS_2013, already processed.
# Skipping NYSE_GIL_2007, already processed.
# Skipping NYSE_LOW_2016, already processed.
# Skipping NYSE_RDS_2012, already processed.
# Skipping NYSE_RDY_2007, already processed.
# Skipping NYSE_IBM_2008, already processed.
# Skipping NYSE_MS_2016, already processed.
# Skipping NYSE_RDS_2016, already processed.
# Skipping NYSE_ADP_2020, already processed.
# Skipping NYSE_ENLC_2020, already processed.
# Skipping NYSE_AES_2018, already processed.
# Skipping NYSE_NAV_2018, already processed.
# Skipping NYSE_AEP_2006, already processed.
# Skipping NYSE_MS_2018, already processed.
# Skipping NYSE_PPG_2012, already processed.
# Skipping NYSE_MTX_2020, already processed.
# Skipping NYSE_KW_2019, already processed.
# Skipping NYSE_WST_2019, already processed.
# Skipping NYSE_MRO_2013, already processed.
# Skipping NYSE_AVB_2016, already processed.
# Skipping NYSE_ADS_2018, already processed.
# Skipping NYSE_FCX_2012, already processed.
# Skipping NYSE_K_2018, already processed.
# Skipping NYSE_OFC_2014, already processed.
# Skipping NYSE_RSG_2020, already processed.
# Skipping NYSE_AWR_2017, already processed.
# Skipping NYSE_BK_2009, already processed.
# Skipping NYSE_MIC_2020, already processed.
# Skipping NYSE_ABC_2017, already processed.
# Skipping NYSE_VMW_2015, already processed.
# Skipping NYSE_ECL_2015, already processed.
# Skipping NYSE_SIG_2017, already processed.
# Skipping NYSE_LOW_2006, already processed.
# Skipping NYSE_NEE_2022, already processed.
# Skipping NYSE_ODP_2017, already processed.
# Skipping NYSE_ITT_2018, already processed.
# Skipping NYSE_NOC_2020, already processed.
# Skipping NYSE_CAJ_2019, already processed.
# Skipping NYSE_ODP_2022, already processed.
# Skipping NYSE_NOC_2017, already processed.
# Skipping NYSE_OIS_2020, already processed.
# Skipping NYSE_BWA_2021, already processed.
# Skipping NYSE_VEDL_2019, already processed.
# Skipping NYSE_HRC_2020, already processed.
# Skipping NYSE_PPL_2020, already processed.
# Skipping NYSE_HT_2017, already processed.
# Skipping NYSE_AIZ_2020, already processed.
# Skipping NYSE_DIS_2012, already processed.
# Skipping NYSE_IQV_2015, already processed.
# Skipping NYSE_ALK_2018, already processed.
# Skipping NYSE_AWK_2016, already processed.
# Skipping NYSE_FDS_2018, already processed.
# Skipping NYSE_CF_2015, already processed.
# Skipping NYSE_IVZ_2021, already processed.
# Skipping NYSE_ALB_2014, already processed.
# Skipping NYSE_AQUA_2015, already processed.
# Skipping NYSE_KO_2021, already processed.
# Skipping NYSE_FDS_2019, already processed.
# Skipping NYSE_CNDT_2021, already processed.
# Skipping NYSE_ITW_2014, already processed.
# Skipping NYSE_VAC_2018, already processed.
# Skipping NYSE_INFY_2009, already processed.
# Skipping NYSE_RELX_2012, already processed.
# Skipping NYSE_EQR_2014, already processed.
# Skipping NYSE_CNP_2020, already processed.
# Skipping NYSE_SCS_2015, already processed.
# Skipping NYSE_CMI_2011, already processed.
# Skipping NYSE_CEIX_2018, already processed.
# Skipping NYSE_BMI_2017, already processed.
# Skipping NYSE_TI_2006, already processed.
# Skipping NYSE_CNX_2020, already processed.
# Skipping NYSE_NP_2020, already processed.
# Skipping NYSE_HDB_2019, already processed.
# Skipping NYSE_RRC_2018, already processed.
# Skipping NYSE_ASGN_2019, already processed.
# Skipping NYSE_hpq_2017, already processed.
# Skipping NYSE_IVC_2021, already processed.
# Skipping NYSE_LND_20200701_20210630, already processed.
# Skipping NYSE_SWN_2015, already processed.
# Skipping NYSE_ECL_2021, already processed.
# Skipping NYSE_TGNA_2019, already processed.
# Skipping NYSE_WM_2017, already processed.
# Skipping NYSE_B_2020, already processed.
# Skipping NYSE_WMT_2016, already processed.
# Skipping NYSE_NSP_2014, already processed.
# Skipping NYSE_KEY_2021, already processed.
# Skipping NYSE_FRT_2019, already processed.
# Skipping NYSE_CPT_2020, already processed.
# Skipping NYSE_HUM_2019, already processed.
# Skipping NYSE_RCL_2011, already processed.
# Skipping NYSE_IBM_2015, already processed.
# Skipping NYSE_CMS_2021, already processed.
# Skipping NYSE_CBRE_2012, already processed.
# Skipping NYSE_NBL_2012, already processed.
# Skipping NYSE_BERY_2021, already processed.
# Skipping NYSE_AQUA_2020, already processed.
# Skipping NYSE_GEF_2011, already processed.
# Skipping NYSE_WM_2016, already processed.
# Skipping NYSE_WMK_2020, already processed.
# Skipping NYSE_RDS_2005, already processed.
# Skipping NYSE_NSC_2009, already processed.
# Skipping NYSE_CI_2017, already processed.
# Skipping NYSE_MUR_2022, already processed.
# Skipping NYSE_FSS_2021, already processed.
# Skipping NYSE_GWW_2012, already processed.
# Skipping NYSE_GM_2020, already processed.
# Skipping NYSE_CHT_2019, already processed.
# Skipping NYSE_KMB_2004, already processed.
# Skipping NYSE_ATO_2019, already processed.
# Skipping NYSE_CAJ_2000, already processed.
# Skipping NYSE_CAG_2020, already processed.
# Skipping NYSE_ROL_2019, already processed.
# Skipping NYSE_PPL_2016, already processed.
# Skipping NYSE_ARCO_2020, already processed.
# Skipping NYSE_WMT_2006, already processed.
# Skipping NYSE_CXP_2021, already processed.
# Skipping NYSE_BAX_2018, already processed.
# Skipping NYSE_WRI_2021, already processed.
# Skipping NYSE_TK_2020, already processed.
# Skipping NYSE_BKD_2016, already processed.
# Skipping NYSE_AVYA_2020, already processed.
# Skipping NYSE_CS_2016, already processed.
# Skipping NYSE_SHW_2018, already processed.
# Skipping NYSE_AVB_2021, already processed.
# Skipping NYSE_PKI_2020, already processed.
# Skipping NYSE_INFY_2021, already processed.
# Skipping NYSE_PG_1999, already processed.
# Skipping NYSE_BCE_2015, already processed.
# Skipping NYSE_KB_2016, already processed.
# Skipping NYSE_OC_2015, already processed.
# Skipping NYSE_VSTO_2021, already processed.
# Skipping NYSE_CMA_2015, already processed.
# Skipping NYSE_JBGS_2019, already processed.
# Skipping NYSE_CMC_2021, already processed.
# Skipping NYSE_RDS_2020, already processed.
# Skipping NYSE_UNP_2020, already processed.
# Skipping NYSE_KOS_2018, already processed.
# Skipping NYSE_ACI_2018, already processed.
# Skipping NYSE_TROX_2015, already processed.
# Skipping NYSE_TT_2014, already processed.
# Skipping NYSE_WLK_2020, already processed.
# Skipping NYSE_ABT_2016, already processed.
# Skipping NYSE_VZ_2020, already processed.
# Skipping NYSE_SWK_2016, already processed.
# Skipping NYSE_DUK_2011, already processed.
# Skipping NYSE_DGX_2018, already processed.
# Skipping NYSE_MTG_2021, already processed.
# Skipping NYSE_DIS_2018, already processed.
# Skipping NYSE_NSP_2015, already processed.
# Skipping NYSE_TM_2011, already processed.
# Skipping NYSE_CS_2015, already processed.
# Skipping NYSE_CVS_2015, already processed.
# Skipping NYSE_CLS_2012, already processed.
# Skipping NYSE_CHT_2008, already processed.
# Skipping NYSE_DDS_2018, already processed.
# Skipping NYSE_ACN_2011, already processed.
# Skipping NYSE_PAYC_2021, already processed.
# Skipping NYSE_KMB_2005, already processed.
# Skipping NYSE_SLG_2019, already processed.
# Skipping NYSE_WM_2011, already processed.
# Skipping NYSE_ABEV_2018, already processed.
# Skipping NYSE_AA_2012, already processed.
# Skipping NYSE_FUL_2018, already processed.
# Skipping NYSE_STM_2002, already processed.
# Skipping NYSE_ALV_2021, already processed.
# Skipping NYSE_KRA_2020, already processed.
# Skipping NYSE_ASIX_2021, already processed.
# Skipping NYSE_APH_2021, already processed.
# Skipping NYSE_CAT_2014, already processed.
# Skipping NYSE_PEG_2017, already processed.
# Skipping NYSE_LXK_2021, already processed.
# Skipping NYSE_DD_2020, already processed.
# Skipping NYSE_VAR_2015, already processed.
# Skipping NYSE_ATI_2022, already processed.
# Skipping NYSE_PH_2020, already processed.
# Skipping NYSE_WMB_2019, already processed.
# Skipping NYSE_PII_2021, already processed.
# Skipping NYSE_ELS_2021, already processed.
# Skipping NYSE_NWL_2019, already processed.
# Skipping NYSE_VRS_2007, already processed.
# Skipping NYSE_HDB_2015, already processed.
# Skipping NYSE_EMN_2018, already processed.
# Skipping NYSE_MTX_2021, already processed.
# Skipping NYSE_VNO_2018, already processed.
# Skipping NYSE_CMI_2004, already processed.
# Skipping NYSE_ALL_2010, already processed.
# Skipping NYSE_GIS_2012, already processed.
# Skipping NYSE_LTHM_2020, already processed.
# Skipping NYSE_PG_2002, already processed.
# Skipping NYSE_ALV_2016, already processed.
# Skipping NYSE_PSA_2022, already processed.
# Skipping NYSE_OFC_2022, already processed.
# Skipping NYSE_HRL_2018, already processed.
# Skipping NYSE_TEN_2021, already processed.
# Skipping NYSE_KRC_2016, already processed.
# Skipping NYSE_CVIA_2018, already processed.
# Skipping NYSE_MGM_2020, already processed.
# Skipping NYSE_MAS_2015, already processed.
# Skipping NYSE_MOS_2021, already processed.
# Skipping NYSE_DELL_1998, already processed.
# Skipping NYSE_UE_2021, already processed.
# Skipping NYSE_AFL_2015, already processed.
# Skipping NYSE_FDX_2019, already processed.
# Skipping NYSE_BA_2019, already processed.
# Skipping NYSE_SLG_2015, already processed.
# Skipping NYSE_KOP_2017, already processed.
# Skipping NYSE_RTX_2018, already processed.
# Skipping NYSE_NWN_2021, already processed.
# Skipping NYSE_NHS_2021, already processed.
# Skipping NYSE_HCC_2021, already processed.
# Skipping NYSE_AXL_2019, already processed.
# Skipping NYSE_MS_2021, already processed.
# Skipping NYSE_DTE_2019, already processed.
# Skipping NYSE_TRU_2018, already processed.
# Skipping NYSE_WCN_2021, already processed.
# Skipping NYSE_GEO_2021, already processed.
# Skipping NYSE_SUPV_2018, already processed.
# Skipping NYSE_EE_2020, already processed.
# Skipping NYSE_LII_2021, already processed.
# Skipping NYSE_BLD_2020, already processed.
# Skipping NYSE_ORA_2017, already processed.
# Skipping NYSE_PVH_2021, already processed.
# Skipping NYSE_WRB_2020, already processed.
# Skipping NYSE_PRU_2018, already processed.
# Skipping NYSE_MU_2018, already processed.
# Skipping NYSE_WMT_2020, already processed.
# Skipping NYSE_ORCL_2016, already processed.
# Skipping NYSE_GSH_2021, already processed.
# Skipping NYSE_IT_2019, already processed.
# Skipping NYSE_EW_2020, already processed.
# Skipping NYSE_ABEV_2019, already processed.
# Skipping NYSE_EVRG_2018, already processed.
# Skipping NYSE_KRA_2017, already processed.
# Skipping NYSE_CAT_2020, already processed.
# Skipping NYSE_BC_2021, already processed.
# Skipping NYSE_SMG_2018, already processed.
# Skipping NYSE_HFC_2020, already processed.
# Skipping NYSE_MMC_2021, already processed.
# Skipping NYSE_NI_2017, already processed.
# Skipping NYSE_WFC_2020, already processed.
# Skipping NYSE_HOG_2020, already processed.
# Skipping NYSE_WRE_2016, already processed.
# Skipping NYSE_DD_2017, already processed.
# Skipping NYSE_AMN_2021, already processed.
# Skipping NYSE_IQV_2013, already processed.
# Skipping NYSE_DPH_2016, already processed.
# Skipping NYSE_MU_2022, already processed.
# Skipping NYSE_UNP_2018, already processed.
# Skipping NYSE_ACM_2017, already processed.
# Skipping NYSE_TNC_2010, already processed.
# Skipping NYSE_DPH_2018, already processed.
# Skipping NYSE_JLL_2018, already processed.
# Skipping NYSE_KMX_20210301_20220228, already processed.
# Skipping NYSE_VLRS_2016, already processed.
# Skipping NYSE_CLR_2017, already processed.
# Skipping NYSE_WFC_2021, already processed.
# Skipping NYSE_CLF_2020, already processed.
# Skipping NYSE_NX_2021, already processed.
# Skipping NYSE_INSW_2019, already processed.
# Skipping NYSE_SHW_2019, already processed.
# Skipping NYSE_EXC_2019, already processed.
# Skipping NYSE_FLO_2017, already processed.
# Skipping NYSE_SEE_2019, already processed.
# Skipping NYSE_NVS_2020, already processed.
# Skipping NYSE_PDM_2020, already processed.
# Skipping NYSE_SITC_2019, already processed.
# Skipping NYSE_PEP_2018, already processed.
# Skipping NYSE_TI_2004, already processed.
# Skipping NYSE_RCI_2014, already processed.
# Skipping NYSE_SXC_2021, already processed.
# Skipping NYSE_CAJ_2014, already processed.
# Skipping NYSE_ABT_2017, already processed.
# Skipping NYSE_PPG_2008, already processed.
# Skipping NYSE_SYK_2019, already processed.
# Skipping NYSE_ATH_2019, already processed.
# Skipping NYSE_MLM_2019, already processed.
# Skipping NYSE_IAG_2020, already processed.
# Skipping NYSE_TXT_2021, already processed.
# Skipping NYSE_SUPV_2020, already processed.
# Skipping NYSE_AHH_2019, already processed.
# Skipping NYSE_TGT_2009, already processed.
# Skipping NYSE_AEP_2022, already processed.
# Skipping NYSE_STT_2013, already processed.
# Skipping NYSE_STT_2008, already processed.
# Skipping NYSE_PCH_2021, already processed.
# Skipping NYSE_CVX_2005, already processed.
# Skipping NYSE_DOC_2020, already processed.
# Skipping NYSE_TX_2018, already processed.
# Skipping NYSE_ALB_2020, already processed.
# Skipping NYSE_GIS_2013, already processed.
# Skipping NYSE_CIT_2020, already processed.
# Skipping NYSE_HES_2009, already processed.
# Skipping NYSE_LEA_2015, already processed.
# Skipping NYSE_AEP_2019, already processed.
# Skipping NYSE_CLNY_2020, already processed.
# Skipping NYSE_TKR_2018, already processed.
# Skipping NYSE_CWT_2019, already processed.
# Skipping NYSE_FNF_2020, already processed.
# Skipping NYSE_ED_2012, already processed.
# Skipping NYSE_CAG_2018, already processed.
# Skipping NYSE_ALB_2016, already processed.
# Skipping NYSE_DUK_2021, already processed.
# Skipping NYSE_CF_2012, already processed.
# Skipping NYSE_ITW_2017, already processed.
# Skipping NYSE_EW_2015, already processed.
# Skipping NYSE_TGNA_2018, already processed.
# Skipping NYSE_GIB_2018, already processed.
# Skipping NYSE_MCO_2012, already processed.
# Skipping NYSE_CWEN_2019, already processed.
# Skipping NYSE_ALL_2007, already processed.
# Skipping NYSE_STT_2012, already processed.
# Skipping NYSE_ETRN_2021, already processed.
# Skipping NYSE_ORA_2011, already processed.
# Skipping NYSE_DE_2020, already processed.
# Skipping NYSE_NGLS_2018, already processed.
# Skipping NYSE_AQUA_2018, already processed.
# Skipping NYSE_TUP_2015, already processed.
# Skipping NYSE_HT_2018, already processed.
# Skipping NYSE_GIS_2018, already processed.
# Skipping NYSE_MRO_2006, already processed.
# Skipping NYSE_ABB_2017, already processed.
# Skipping NYSE_CHL_2012, already processed.
# Skipping NYSE_HRB_2020, already processed.
# Skipping NYSE_NLSN_2018, already processed.
# Skipping NYSE_NVS_2012, already processed.
# Skipping NYSE_AMT_2020, already processed.
# Skipping NYSE_OGS_2019, already processed.
# Skipping NYSE_ATI_2021, already processed.
# Skipping NYSE_EE_2018, already processed.
# Skipping NYSE_AEP_2008, already processed.
# Skipping NYSE_WELL_2015, already processed.
# Skipping NYSE_HRL_2009, already processed.
# Skipping NYSE_CI_2019, already processed.
# Skipping NYSE_ABEV_2021, already processed.
# Skipping NYSE_EXR_2020, already processed.
# Skipping NYSE_CPE_2019, already processed.
# Skipping NYSE_X_2017, already processed.
# Skipping NYSE_LVS_2016, already processed.
# Skipping NYSE_CNDT_2020, already processed.
# Skipping NYSE_CLS_2020, already processed.
# Skipping NYSE_IQV_2018, already processed.
# Skipping NYSE_LII_2015, already processed.
# Skipping NYSE_AA_2013, already processed.
# Skipping NYSE_NOMD_2017, already processed.
# Skipping NYSE_SMP_2021, already processed.
# Skipping NYSE_FRT_2020, already processed.
# Skipping NYSE_VAR_2016, already processed.
# Skipping NYSE_MU_2019, already processed.
# Skipping NYSE_DOOR_2020, already processed.
# Skipping NYSE_BHP_2012, already processed.
# Skipping NYSE_MO_2012, already processed.
# Skipping NYSE_PSN_2015, already processed.
# Skipping NYSE_EIX_2020, already processed.
# Skipping NYSE_MTW_2020, already processed.
# Skipping NYSE_ABBV_2020, already processed.
# Skipping NYSE_DCI_2020, already processed.
# Skipping NYSE_MSI_2021, already processed.
# Skipping NYSE_KMB_2007, already processed.
# Skipping NYSE_CHH_2019, already processed.
# Skipping NYSE_PG_2014, already processed.
# Skipping NYSE_PAM_2017, already processed.
# Skipping NYSE_RSG_2016, already processed.
# Skipping NYSE_CLH_2020, already processed.
# Skipping NYSE_KSS_2014, already processed.
# Skipping NYSE_SPG_2020, already processed.
# Skipping NYSE_WBS_2018, already processed.
# Skipping NYSE_TRV_2019, already processed.
# Skipping NYSE_CBZ_2018, already processed.
# Skipping NYSE_DRE_2020, already processed.
# Skipping NYSE_AES_2015, already processed.
# Skipping NYSE_VALE_2016, already processed.
# Skipping NYSE_TK_2016, already processed.
# Skipping NYSE_CMP_2015, already processed.
# Skipping NYSE_AWR_2021, already processed.
# Skipping NYSE_TECK_2009, already processed.
# Skipping NYSE_NRG_2018, already processed.
# Skipping NYSE_FLNG_2020, already processed.
# Skipping NYSE_TFX_2020, already processed.
# Skipping NYSE_PRU_2019, already processed.
# Skipping NYSE_ECL_2006, already processed.
# Skipping NYSE_ACH_2019, already processed.
# Skipping NYSE_SON_2021, already processed.
# Skipping NYSE_TMO_2011, already processed.
# Skipping NYSE_TRU_2014, already processed.
# Skipping NYSE_GS_2014, already processed.
# Skipping NYSE_ALB_2010, already processed.
# Skipping NYSE_CHK_2012, already processed.
# Skipping NYSE_HUN_2020, already processed.
# Skipping NYSE_TPR_2020, already processed.
# Skipping NYSE_BTU_2014, already processed.
# Skipping NYSE_PEAK_2019, already processed.
# Skipping NYSE_EPC_2020, already processed.
# Skipping NYSE_HES_2012, already processed.
# Skipping NYSE_ETN_2018, already processed.
# Skipping NYSE_AWK_2019, already processed.
# Skipping NYSE_UPS_2018, already processed.
# Skipping NYSE_HON_2021, already processed.
# Skipping NYSE_DUK_2016, already processed.
# Skipping NYSE_BHP_2004, already processed.
# Skipping NYSE_NOC_2012, already processed.
# Skipping NYSE_MTOR_2021, already processed.
# Skipping NYSE_ECL_2017, already processed.
# Skipping NYSE_SM_2021, already processed.
# Skipping NYSE_EOG_2017, already processed.
# Skipping NYSE_EGY_2020, already processed.
# Skipping NYSE_SYY_2019, already processed.
# Skipping NYSE_IFF_2021, already processed.
# Skipping NYSE_XOM_2018, already processed.
# Skipping NYSE_NSP_2013, already processed.
# Skipping NYSE_LLY_2015, already processed.
# Skipping NYSE_GSH_2019, already processed.
# Skipping NYSE_ALL_2005, already processed.
# Skipping NYSE_TROX_2019, already processed.
# Skipping NYSE_ESS_2021, already processed.
# Skipping NYSE_SE_2021, already processed.
# Skipping NYSE_JNJ_2013, already processed.
# Skipping NYSE_MTD_2018, already processed.
# Skipping NYSE_ARE_2020, already processed.
# Skipping NYSE_CWT_2015_2016, already processed.
# Skipping NYSE_GL_2018, already processed.
# Skipping NYSE_AGN_2018, already processed.
# Skipping NYSE_TT_2016, already processed.
# Skipping NYSE_MTD_2015, already processed.
# Skipping NYSE_A_2017, already processed.
# Skipping NYSE_JLL_2017, already processed.
# Skipping NYSE_SUM_2021, already processed.
# Skipping NYSE_DRE_2016, already processed.
# Skipping NYSE_EMN_2019, already processed.
# Skipping NYSE_DNR_2015, already processed.
# Skipping NYSE_JPM_2015, already processed.
# Skipping NYSE_MO_2013, already processed.
# Skipping NYSE_VZ_2018, already processed.
# Skipping NYSE_HES_2018, already processed.
# Skipping NYSE_HLT_2018, already processed.
# Skipping NYSE_AMX_2017, already processed.
# Skipping NYSE_GIB_2020, already processed.
# Skipping NYSE_WU_2021, already processed.
# Skipping NYSE_RSG_2017, already processed.
# Skipping NYSE_AR_2020, already processed.
# Skipping NYSE_KNL_2012, already processed.
# Skipping NYSE_VEDL_2020, already processed.
# Skipping NYSE_hpq_2011, already processed.
# Skipping NYSE_NTR_2021, already processed.
# Skipping NYSE_FCX_2010, already processed.
# Skipping NYSE_CPA_2020, already processed.
# Skipping NYSE_MMM_2021, already processed.
# Skipping NYSE_NRG_2021, already processed.
# Skipping NYSE_STAR_2019, already processed.
# Skipping NYSE_RLGY_2020, already processed.
# Skipping NYSE_MRC_2020, already processed.
# Skipping NYSE_HLT_2017, already processed.
# Skipping NYSE_LMT_2018, already processed.
# Skipping NYSE_ORCL_2018, already processed.
# Skipping NYSE_CAJ_2020, already processed.
# Skipping NYSE_CL_2014, already processed.
# Skipping NYSE_PRI_2020, already processed.
# Skipping NYSE_KBH_2009, already processed.
# Skipping NYSE_BCE_2014, already processed.
# Skipping NYSE_LXK_2016, already processed.
# Skipping NYSE_COP_2018, already processed.
# Skipping NYSE_UNH_2019, already processed.
# Skipping NYSE_WLK_2019, already processed.
# Skipping NYSE_PSX_2022, already processed.
# Skipping NYSE_TI_2007, already processed.
# Skipping NYSE_ECL_2013, already processed.
# Skipping NYSE_FDS_2017, already processed.
# Skipping NYSE_SXT_2017, already processed.
# Skipping NYSE_MRO_2016, already processed.
# Skipping NYSE_ALB_2019, already processed.
# Skipping NYSE_FDP_2019, already processed.
# Skipping NYSE_ED_2009, already processed.
# Skipping NYSE_HLT_2020, already processed.
# Skipping NYSE_DDS_2019, already processed.
# Skipping NYSE_CS_2019, already processed.
# Skipping NYSE_NFG_2011, already processed.
# Skipping NYSE_FLR_2021, already processed.
# Skipping NYSE_AIV_2019, already processed.
# Skipping NYSE_NS_2020, already processed.
# Skipping NYSE_MRO_2001, already processed.
# Skipping NYSE_ZMH_2016, already processed.
# Skipping NYSE_HSY_2014, already processed.
# Skipping NYSE_EPD_2021, already processed.
# Skipping NYSE_WSM_2015, already processed.
# Skipping NYSE_KEYS_2021, already processed.
# Skipping NYSE_SHO_2019, already processed.
# Skipping NYSE_HES_2002, already processed.
# Skipping NYSE_EURN_2021, already processed.
# Skipping NYSE_CS_2013, already processed.
# Skipping NYSE_MSI_2018, already processed.
# Skipping NYSE_TI_2016, already processed.
# Skipping NYSE_LNC_2019, already processed.
# Skipping NYSE_CPRI_2020, already processed.
# Skipping NYSE_NOC_2008, already processed.
# Skipping NYSE_CPB_2016, already processed.
# Skipping NYSE_CHH_2021, already processed.
# Skipping NYSE_PCG_2019, already processed.
# Skipping NYSE_DELL_2006, already processed.
# Skipping NYSE_HBAN_2019, already processed.
# Skipping NYSE_AMX_2012, already processed.
# Skipping NYSE_TGT_2010, already processed.
# Skipping NYSE_FCAU_2014, already processed.
# Skipping NYSE_AIG_2020, already processed.
# Skipping NYSE_SHG_2015, already processed.
# Skipping NYSE_RSG_2015, already processed.
# Skipping NYSE_MCD_2012, already processed.
# Skipping NYSE_CTL_2019, already processed.
# Skipping NYSE_LND_20150701_20160630, already processed.
# Skipping NYSE_TEVA_2014, already processed.
# Skipping NYSE_NFG_2019, already processed.
# Skipping NYSE_RDY_2021, already processed.
# Skipping NYSE_BURL_2019, already processed.
# Skipping NYSE_EQT_2016, already processed.
# Skipping NYSE_ESE_2017, already processed.
# Skipping NYSE_DHR_2022, already processed.
# Skipping NYSE_KSS_2017, already processed.
# Skipping NYSE_MUR_2020, already processed.
# Skipping NYSE_BK_2011, already processed.
# Skipping NYSE_SJM_2019, already processed.
# Skipping NYSE_KIM_2015, already processed.
# Skipping NYSE_FMC_2019, already processed.
# Skipping NYSE_NAV_2014, already processed.
# Skipping NYSE_BLL_2020, already processed.
# Skipping NYSE_OFC_2019, already processed.
# Skipping NYSE_ABC_2016, already processed.
# Skipping NYSE_MTW_2019, already processed.
# Skipping NYSE_UNF_2019, already processed.
# Skipping NYSE_CVEO_2021, already processed.
# Skipping NYSE_ABEV_2017, already processed.
# Skipping NYSE_PEB_2019, already processed.
# Skipping NYSE_MDP_2019, already processed.
# Skipping NYSE_SO_2017, already processed.
# Skipping NYSE_DNOW_2021, already processed.
# Skipping NYSE_CAG_2013, already processed.
# Skipping NYSE_AZ_2021, already processed.
# Skipping NYSE_FCN_2016, already processed.
# Skipping NYSE_SLB_2016, already processed.
# Skipping NYSE_H_2017, already processed.
# Skipping NYSE_SPP_2016, already processed.
# Skipping NYSE_SHG_2014, already processed.
# Skipping NYSE_SE_2016, already processed.
# Skipping NYSE_ALB_2013, already processed.
# Skipping NYSE_TI_2020, already processed.
# Skipping NYSE_DUK_2012, already processed.
# Skipping NYSE_STT_2015, already processed.
# Skipping NYSE_ETN_2020, already processed.
# Skipping NYSE_ALLY_2019, already processed.
# Skipping NYSE_YUMC_2020, already processed.
# Skipping NYSE_TM_2016, already processed.
# Skipping NYSE_CPS_2018, already processed.
# Skipping NYSE_RCL_2008, already processed.
# Skipping NYSE_SE_2019, already processed.
# Skipping NYSE_KMB_2013, already processed.
# Skipping NYSE_BBY_2020, already processed.
# Skipping NYSE_TROX_2018, already processed.
# Skipping NYSE_WRE_2020, already processed.
# Skipping NYSE_EMN_2014, already processed.
# Skipping NYSE_AVP_2021, already processed.
# Skipping NYSE_TNC_2009, already processed.
# Skipping NYSE_MAXR_2020, already processed.
# Skipping NYSE_LOW_2007, already processed.
# Skipping NYSE_KMB_2015, already processed.
# Skipping NYSE_NSC_2012, already processed.
# Skipping NYSE_OC_2017, already processed.
# Skipping NYSE_LVS_2012, already processed.
# Skipping NYSE_RF_2020, already processed.
# Skipping NYSE_CAH_2018, already processed.
# Skipping NYSE_DD_2021, already processed.
# Skipping NYSE_B_2019, already processed.
# Skipping NYSE_EVRG_2019, already processed.
# Skipping NYSE_AEP_2016, already processed.
# Skipping NYSE_PEB_2020, already processed.
# Skipping NYSE_RDS_2006, already processed.
# Skipping NYSE_C_2018, already processed.
# Skipping NYSE_ECL_2020, already processed.
# Skipping NYSE_VNE_2021, already processed.
# Skipping NYSE_LMT_2013, already processed.
# Skipping NYSE_TT_2020, already processed.
# Skipping NYSE_TYL_2019, already processed.
# Skipping NYSE_MPC_2015, already processed.
# Skipping NYSE_CHK_2016, already processed.
# Skipping NYSE_TROX_2020, already processed.
# Skipping NYSE_KAI_2020, already processed.
# Skipping NYSE_MTD_2014, already processed.
# Skipping NYSE_NKE_2011, already processed.
# Skipping NYSE_ARE_2018, already processed.
# Skipping NYSE_RHT_2020, already processed.
# Skipping NYSE_VICI_2020, already processed.
# Skipping NYSE_HASI_2019, already processed.
# Skipping NYSE_NKE_2015, already processed.
# Skipping NYSE_KMB_2011, already processed.
# Skipping NYSE_WMS_2022, already processed.
# Skipping NYSE_TMX_2021, already processed.
# Skipping NYSE_CPB_20200803-20210801, already processed.
# Skipping NYSE_NRG_2019, already processed.
# Skipping NYSE_K_2013, already processed.
# Skipping NYSE_CCL_2017, already processed.
# Skipping NYSE_RDY_2004, already processed.
# Skipping NYSE_LEA_2020, already processed.
# Skipping NYSE_DOW_2017, already processed.
# Skipping NYSE_ACH_2017, already processed.
# Skipping NYSE_LXK_2017, already processed.
# Skipping NYSE_PBI_2020, already processed.
# Skipping NYSE_KAI_2021, already processed.
# Skipping NYSE_MPC_2013, already processed.
# Skipping NYSE_WHR_2012, already processed.
# Skipping NYSE_IFF_2013, already processed.
# Skipping NYSE_MO_2018, already processed.
# Skipping NYSE_TECK_2007, already processed.
# Skipping NYSE_TK_2013, already processed.
# Skipping NYSE_WMT_2015, already processed.
# Skipping NYSE_LND_2018, already processed.
# Skipping NYSE_DIS_2009, already processed.
# Skipping NYSE_HUM_2017, already processed.
# Skipping NYSE_CLS_2019, already processed.
# Skipping NYSE_OUT_2019, already processed.
# Skipping NYSE_BF_2009_2010, already processed.
# Skipping NYSE_BTE_2020, already processed.
# Skipping NYSE_LDOS_2020, already processed.
# Skipping NYSE_ES_2018, already processed.
# Skipping NYSE_BKI_2020, already processed.
# Skipping NYSE_HSY_2016, already processed.
# Skipping NYSE_WYND_2019, already processed.
# Skipping NYSE_CPS_2020, already processed.
# Skipping NYSE_SKT_2021, already processed.
# Skipping NYSE_AXL_2021, already processed.
# Skipping NYSE_F_2018, already processed.
# Skipping NYSE_ADT_2021, already processed.
# Skipping NYSE_IT_2021, already processed.
# Skipping NYSE_ECL_2014, already processed.
# Skipping NYSE_WBS_2019, already processed.
# Skipping NYSE_VTR_2018, already processed.
# Skipping NYSE_DELL_2002, already processed.
# Skipping NYSE_IGT_2017, already processed.
# Skipping NYSE_WRB_2019, already processed.
# Skipping NYSE_MRO_2004, already processed.
# Skipping NYSE_CAJ_2008, already processed.
# ...
# Skipping NYSE_LPL_2013, already processed.
# Skipping NYSE_hpq_2009, already processed.
# Skipping NYSE_TFX_2021, already processed.
# Skipping NYSE_VIPS_2019, already processed.
# Skipping NYSE_JNJ_2016, already processed.
# Skipping NYSE_KOS_2019, already processed.
# Skipping NYSE_YUM_2020, already processed.
# Skipping NYSE_FDX_2013, already processed.
# Skipping NYSE_CBT_2013, already processed.
# Skipping NYSE_JLL_2019, already processed.
# Skipping NYSE_M_2018, already processed.
# Skipping NYSE_KRC_2017, already processed.
# Skipping NYSE_MCO_2018, already processed.
# Skipping NYSE_BA_2021, already processed.
# Skipping NYSE_ECL_2008, already processed.
# Skipping NYSE_TI_2018, already processed.
# Skipping NYSE_VST_2019, already processed.
# Skipping NYSE_CCK_2011, already processed.
# Skipping NYSE_LNC_2021, already processed.
# Skipping NYSE_WCN_2019, already processed.
# Skipping NYSE_HD_2017, already processed.
# Skipping NYSE_APTV_2020, already processed.
# Skipping NYSE_IBM_2011, already processed.
# Skipping NYSE_CIEN_2018, already processed.
# Skipping NYSE_LMT_2016, already processed.
# Skipping NYSE_SCS_2019, already processed.
# Skipping NYSE_NOC_2009, already processed.
# Skipping NYSE_BMI_2020_2021, already processed.
# Skipping NYSE_CPB_2019, already processed.
# Skipping NYSE_TIF_2018, already processed.
# Skipping NYSE_CCK_2021, already processed.
# Skipping NYSE_GIS_2021, already processed.
# Skipping NYSE_RELX_2016, already processed.
# Skipping NYSE_RMD_2017, already processed.
# Skipping NYSE_CBT_2019, already processed.
# Skipping NYSE_ACM_2012, already processed.
# Skipping NYSE_QTS_2019, already processed.
# Skipping NYSE_DUK_2008, already processed.
# Skipping NYSE_RCL_2021, already processed.
# Skipping NYSE_PLD_2008, already processed.
# Skipping NYSE_PXD_2019, already processed.
# Skipping NYSE_FDX_2018, already processed.
# Skipping NYSE_CUB_2020, already processed.
# Skipping NYSE_FLR_2008, already processed.
# Skipping NYSE_IAG_2021, already processed.
# Skipping NYSE_VZ_2005, already processed.
# Skipping NYSE_MA_2017, already processed.
# Skipping NYSE_ZBH_2017, already processed.
# Skipping NYSE_EQT_2021, already processed.
# Skipping NYSE_MAS_2003, already processed.
# Skipping NYSE_SWX_2018, already processed.
# Skipping NYSE_THO_2019, already processed.
# Skipping NYSE_MOS_2015, already processed.
# Skipping NYSE_ALLY_2017, already processed.
# Skipping NYSE_BTE_2014, already processed.
# Skipping NYSE_K_2011, already processed.
# Skipping NYSE_LDOS_2014, already processed.
# Skipping NYSE_NGLS_2020, already processed.
# Skipping NYSE_LVS_2014, already processed.
# Skipping NYSE_PACK_2019, already processed.
# Skipping NYSE_BBY_2014, already processed.
# Skipping NYSE_CMI_2017, already processed.
# Skipping NYSE_TDC_2015, already processed.
# Skipping NYSE_UVV_2020, already processed.
# Skipping NYSE_DPH_2019, already processed.
# Skipping NYSE_CRGY_2020, already processed.
# Skipping NYSE_APH_2018, already processed.
# Skipping NYSE_PSN_2022, already processed.
# Skipping NYSE_OEC_2019, already processed.
# Skipping NYSE_CVX_2016, already processed.
# Skipping NYSE_SPP_2018, already processed.
# Skipping NYSE_NEE_2021, already processed.
# Skipping NYSE_DUK_2017, already processed.
# Skipping NYSE_PPG_2010, already processed.
# Skipping NYSE_HD_2019, already processed.
# Skipping NYSE_ARCO_2021, already processed.
# Skipping NYSE_FLR_2009, already processed.
# Skipping NYSE_ACN_2014, already processed.
# Skipping NYSE_WMT_2011, already processed.
# Skipping NYSE_TSN_2013, already processed.
# Skipping NYSE_IEX_2020, already processed.
# Skipping NYSE_DCI_2021, already processed.
# Skipping NYSE_CAH_2019, already processed.
# Skipping NYSE_CSTM_2016, already processed.
# Skipping NYSE_PBR_2010, already processed.
# Skipping NYSE_CFG_2019, already processed.
# Skipping NYSE_FCX_2009, already processed.
# Skipping NYSE_MS_2009, already processed.
# Skipping NYSE_ETN_2019, already processed.
# Skipping NYSE_EVA_2021, already processed.
# Skipping NYSE_IP_2015, already processed.
# Skipping NYSE_VC_2019, already processed.
# Skipping NYSE_CAJ_2005, already processed.
# Skipping NYSE_CWK_2019, already processed.
# Skipping NYSE_WTS_2017, already processed.
# Skipping NYSE_JPM_2018, already processed.
# Skipping NYSE_GVA_2014, already processed.
# Skipping NYSE_HRL_2016, already processed.
# Skipping NYSE_XOM_2012, already processed.
# Skipping NYSE_HOME_2021, already processed.
# Skipping NYSE_LLY_2010, already processed.
# Skipping NYSE_AA_2018, already processed.
# Skipping NYSE_CHL_2020, already processed.
# Skipping NYSE_EMN_2022, already processed.
# Skipping NYSE_GS_2011, already processed.
# Skipping NYSE_CBRE_2016, already processed.
# Skipping NYSE_BXP_2018, already processed.
# Skipping NYSE_DEI_2020, already processed.
# Skipping NYSE_VALE_2018, already processed.
# Skipping NYSE_WWW_2017, already processed.
# Skipping NYSE_MPC_2017, already processed.
# Skipping NYSE_FTV_2020, already processed.
# Skipping NYSE_FHN_2020, already processed.
# Skipping NYSE_REG_2019, already processed.
# Skipping NYSE_OIS_2022, already processed.
# Skipping NYSE_KOP_2021, already processed.
# Skipping NYSE_HFC_2016, already processed.
# Skipping NYSE_ED_2015, already processed.
# Skipping NYSE_STZ_2019, already processed.
# Skipping NYSE_AVP_2016, already processed.
# Skipping NYSE_CHL_2016, already processed.
# Skipping NYSE_EXC_2018, already processed.
# Skipping NYSE_CHD_2017, already processed.
# Skipping NYSE_SNE_2021, already processed.
# Skipping NYSE_KBH_2007, already processed.
# Skipping NYSE_HRL_2014, already processed.
# Skipping NYSE_ALL_2016, already processed.
# Skipping NYSE_UNM_2015, already processed.
# Skipping NYSE_AQUA_2016, already processed.
# Skipping NYSE_CHT_2016, already processed.
# Skipping NYSE_ODP_2018, already processed.
# Skipping NYSE_OIS_2019, already processed.
# Skipping NYSE_EW_2014, already processed.
# Skipping NYSE_MCO_2014, already processed.
# Skipping NYSE_PPG_2016, already processed.
# Skipping NYSE_DAL_2017, already processed.
# Skipping NYSE_VMI_2021, already processed.
# Skipping NYSE_FUL_2014, already processed.
# Skipping NYSE_SEE_2016, already processed.
# Skipping NYSE_ECL_2016, already processed.
# Skipping NYSE_CPS_2016, already processed.
# Skipping NYSE_LAZ_2018, already processed.
# Skipping NYSE_SEE_2020, already processed.
# Skipping NYSE_WF_2020, already processed.
# Skipping NYSE_DOX_2015, already processed.
# Skipping NYSE_IRM_2013, already processed.
# Skipping NYSE_PM_2021, already processed.
# Skipping NYSE_DCI_2013, already processed.
# Skipping NYSE_RCI_2012, already processed.
# Skipping NYSE_ACC_2020, already processed.
# Skipping NYSE_B_2017, already processed.
# Skipping NYSE_EQT_2018, already processed.
# Skipping NYSE_CVA_2021, already processed.
# Skipping NYSE_HOG_2013, already processed.
# Skipping NYSE_WM_2010, already processed.
# Skipping NYSE_SNE_1997, already processed.
# Skipping NYSE_DPS_2019, already processed.
# Skipping NYSE_HLX_2021, already processed.
# Skipping NYSE_WSM_2019, already processed.
# Skipping NYSE_INFY_2012, already processed.
# Skipping NYSE_BDX_2013, already processed.
# Skipping NYSE_INGR_2016, already processed.
# Skipping NYSE_IGT_2021, already processed.
# Skipping NYSE_HRL_2007, already processed.
# Skipping NYSE_PPL_2018, already processed.
# Skipping NYSE_OUT_2020, already processed.
# Skipping NYSE_RAD_2021, already processed.
# Skipping NYSE_VALE_2010, already processed.
# Skipping NYSE_KBH_2021, already processed.
# Skipping NYSE_PBR_2016, already processed.
# Skipping NYSE_UNP_2017, already processed.
# Skipping NYSE_WFC_2017, already processed.
# Skipping NYSE_CBRE_2020, already processed.
# Skipping NYSE_BTU_2012, already processed.
# Skipping NYSE_FCX_2019, already processed.
# Skipping NYSE_BRX_2018, already processed.
# Skipping NYSE_SMG_2022, already processed.
# Skipping NYSE_PXD_2021, already processed.
# Skipping NYSE_AEP_2015, already processed.
# Skipping NYSE_WFC_2018, already processed.
# Skipping NYSE_RELX_2018, already processed.
# Skipping NYSE_WES_2021, already processed.
# Skipping NYSE_QTS_2021, already processed.
# Skipping NYSE_H_2016, already processed.
# Skipping NYSE_CWEN_2021, already processed.
# Skipping NYSE_CHH_2020, already processed.
# Skipping NYSE_TSN_2019, already processed.
# Skipping NYSE_COP_2013, already processed.
# Skipping NYSE_LLY_2021, already processed.
# Skipping NYSE_TDC_2013, already processed.
# Skipping NYSE_KMB_2019, already processed.
# Skipping NYSE_B_2021, already processed.
# Skipping NYSE_IBA_2020, already processed.
# Skipping NYSE_Y_2020, already processed.
# Skipping NYSE_BTE_2018, already processed.
# Skipping NYSE_VVV_2020, already processed.
# Skipping NYSE_SON_2020, already processed.
# Skipping NYSE_BKR_2018, already processed.
# Skipping NYSE_ASX_2021, already processed.
# Skipping NYSE_BBY_2016, already processed.
# Skipping NYSE_DLR_2018, already processed.
# Skipping NYSE_RELX_2011, already processed.
# Skipping NYSE_BDX_2012, already processed.
# Skipping NYSE_PEG_2019, already processed.
# Skipping NYSE_WEC_2020, already processed.
# Skipping NYSE_IBA_2021, already processed.
# Skipping NYSE_CVS_2020, already processed.
# Skipping NYSE_SNE_2003, already processed.
# Skipping NYSE_KSS_2019, already processed.
# Skipping NYSE_APD_2020, already processed.
# Skipping NYSE_PEG_2015, already processed.
# Skipping NYSE_LNC_2018, already processed.
# Skipping NYSE_MIC_2021, already processed.
# Skipping NYSE_HAS_2017, already processed.
# Skipping NYSE_ALEX_2021, already processed.
# Skipping NYSE_ADNT_2020, already processed.
# Skipping NYSE_TECK_2020, already processed.
# Skipping NYSE_TJX_2015, already processed.
# Skipping NYSE_OSG_2016, already processed.
# Skipping NYSE_TECK_2011, already processed.
# Skipping NYSE_GTES_2019, already processed.
# Skipping NYSE_SRE_2017, already processed.
# Skipping NYSE_CVX_2017, already processed.
# Skipping NYSE_HL_2019, already processed.
# Skipping NYSE_CHD_2021, already processed.
# Skipping NYSE_BLL_2007, already processed.
# Skipping NYSE_ZMH_2018, already processed.
# Skipping NYSE_IAG_2011, already processed.
# Skipping NYSE_EL_2020, already processed.
# Skipping NYSE_hpq_2013, already processed.
# Skipping NYSE_AJG_2018, already processed.
# Skipping NYSE_FMX_2021, already processed.
# Skipping NYSE_X_2020, already processed.
# Skipping NYSE_BG_2018, already processed.
# Skipping NYSE_ENLC_2019, already processed.
# Skipping NYSE_KMI_2021, already processed.
# Skipping NYSE_GLT_2019, already processed.
# Skipping NYSE_MO_2019, already processed.
# Skipping NYSE_SBS_2017, already processed.
# Skipping NYSE_DRE_2015, already processed.
# Skipping NYSE_TM_2008, already processed.
# Skipping NYSE_HES_2004, already processed.
# Skipping NYSE_UE_2020, already processed.
# Skipping NYSE_E_2020, already processed.
# Skipping NYSE_SLB_2015, already processed.
# Skipping NYSE_ORCL_2020, already processed.
# Skipping NYSE_AMP_2017, already processed.
# Skipping NYSE_PLD_2019, already processed.
# Skipping NYSE_SYY_2021, already processed.
# Skipping NYSE_FLNG_2018, already processed.
# Skipping NYSE_CF_2013, already processed.
# Skipping NYSE_ADS_2014, already processed.
# Skipping NYSE_TDW_2020, already processed.
# Skipping NYSE_NSC_2020, already processed.
# Skipping NYSE_CLS_2016, already processed.
# Skipping NYSE_CNX_2014, already processed.
# Skipping NYSE_CMI_2007, already processed.
# Skipping NYSE_ABT_2015, already processed.
# Skipping NYSE_STM_2011, already processed.
# Skipping NYSE_ED_2010, already processed.
# Skipping NYSE_BYD_2021, already processed.
# Skipping NYSE_MCO_2017, already processed.
# Skipping NYSE_PDM_2018, already processed.
# Skipping NYSE_KOP_2009, already processed.
# Skipping NYSE_SKT_2018, already processed.
# Skipping NYSE_XOM_2013, already processed.
# Skipping NYSE_OMC_2018, already processed.
# Skipping NYSE_TBI_2022, already processed.
# Skipping NYSE_JEC_2016, already processed.
# Skipping NYSE_ADM_2021, already processed.
# Skipping NYSE_HOG_2008, already processed.
# Skipping NYSE_TX_2021, already processed.
# Skipping NYSE_ONTO_2021, already processed.
# Skipping NYSE_HI_2021, already processed.
# Skipping NYSE_KIM_2014, already processed.
# Skipping NYSE_OC_2007, already processed.
# Skipping NYSE_PEP_2012, already processed.
# Skipping NYSE_MO_2011, already processed.
# Skipping NYSE_EME_2019, already processed.
# Skipping NYSE_KOP_2008, already processed.
# Skipping NYSE_YUMC_2021, already processed.
# Skipping NYSE_IDA_2018, already processed.
# Skipping NYSE_RIG_2018, already processed.
# Skipping NYSE_MAN_2020, already processed.
# Skipping NYSE_INGR_2011, already processed.
# Skipping NYSE_TK_2021, already processed.
# Skipping NYSE_SYT_2020, already processed.
# Skipping NYSE_DIS_2016, already processed.
# Skipping NYSE_HFC_2018, already processed.
# Skipping NYSE_AA_2017, already processed.
# Skipping NYSE_WMT_2014, already processed.
# Skipping NYSE_CIO_2020, already processed.
# Skipping NYSE_AFL_2016, already processed.
# Skipping NYSE_SYF_2021, already processed.
# Skipping NYSE_SLB_2014, already processed.
# Skipping NYSE_SEE_2015, already processed.
# Skipping NYSE_A_2014, already processed.
# Skipping NYSE_YUM_2017, already processed.
# Skipping NYSE_KMT_2020, already processed.
# Skipping NYSE_TNC_2016, already processed.
# Skipping NYSE_PG_2013, already processed.
# Skipping NYSE_INFY_2010, already processed.
# Skipping NYSE_CPS_2017_19acc6731a1542cca99dde3385095ced, already processed.
# Skipping NYSE_ACI_2016, already processed.
# Skipping NYSE_PLD_2017, already processed.
# Skipping NYSE_MLM_2020, already processed.
# Skipping NYSE_GPS_2007, already processed.
# Skipping NYSE_GSH_2008, already processed.
# Skipping NYSE_LXK_2011, already processed.
# Skipping NYSE_JLL_2013, already processed.
# Skipping NYSE_VMI_2022, already processed.
# Skipping NYSE_BHP_2010, already processed.
# Skipping NYSE_MTB_2020, already processed.
# Skipping NYSE_KSS_2020, already processed.
# Skipping NYSE_SPGI_2020, already processed.
# Skipping NYSE_AVNT_2021, already processed.
# Skipping NYSE_PCH_2019, already processed.
# Skipping NYSE_NLSN_2022, already processed.
# Skipping NYSE_CUZ_2018, already processed.
# Skipping NYSE_VOYA_2021, already processed.
# Skipping NYSE_CAJ_2012, already processed.
# Skipping NYSE_BCE_2016, already processed.
# Skipping NYSE_CS_2020, already processed.
# Skipping NYSE_DAL_2020, already processed.
# Skipping NYSE_WU_2018, already processed.
# Skipping NYSE_PCG_2015, already processed.
# Skipping NYSE_BC_2019, already processed.
# Skipping NYSE_CNHI_2013, already processed.
# Skipping NYSE_CLW_2021, already processed.
# Skipping NYSE_CVX_2018, already processed.
# Skipping NYSE_PCG_2021, already processed.
# Skipping NYSE_MO_2010, already processed.
# Skipping NYSE_APA_2015, already processed.
# Skipping NYSE_GIB_2014, already processed.
# Skipping NYSE_DVN_2020, already processed.
# Skipping NYSE_NLSN_2020, already processed.
# Skipping NYSE_WNC_2021, already processed.
# Skipping NYSE_MSM_2021, already processed.
# Skipping NYSE_CWT_2018, already processed.
# Skipping NYSE_WAT_2012, already processed.
# Skipping NYSE_KEY_2017, already processed.
# Skipping NYSE_STM_1999, already processed.
# Skipping NYSE_ALL_2004, already processed.
# Skipping NYSE_RHP_2019, already processed.
# Skipping NYSE_WBS_2020, already processed.
# Skipping NYSE_HAS_2010, already processed.
# Skipping NYSE_WELL_2017, already processed.
# Skipping NYSE_RDY_2020, already processed.
# Skipping NYSE_STM_2017, already processed.
# Skipping NYSE_MMM_2014, already processed.
# Skipping NYSE_STOR_2021, already processed.
# Skipping NYSE_LNC_2020, already processed.
# Skipping NYSE_BABA_2017_2018, already processed.
# Skipping NYSE_ALB_2008, already processed.
# Skipping NYSE_PKG_2018, already processed.
# Skipping NYSE_ROL_2020, already processed.
# Skipping NYSE_TPR_2016, already processed.
# Skipping NYSE_RCL_2009, already processed.
# Skipping NYSE_VVV_2019, already processed.
# Skipping NYSE_MTG_2020, already processed.
# Skipping NYSE_SLG_2013, already processed.
# Skipping NYSE_AMN_2020, already processed.
# Skipping NYSE_PBI_2019, already processed.
# Skipping NYSE_CPE_2020, already processed.
# Skipping NYSE_HL_2020, already processed.
# Skipping NYSE_ACM_2011, already processed.
# Skipping NYSE_LPL_2019, already processed.
# Skipping NYSE_LOW_2013, already processed.
# Skipping NYSE_CNO_2019, already processed.
# Skipping NYSE_ABBV_2019, already processed.
# Skipping NYSE_GEO_2018, already processed.

# %%
import os

def process_specific(folder_path, tool):
    """
    僅處理指定資料夾內的 dense_regions.json：
    - 將其重新命名為 *_v0_extract_text.json
    - 使用 preprocess_text 處理並產生 *_v1_preprocessed_tool.json
    """
    folder_name = os.path.basename(folder_path)
    new_json_path = os.path.join(folder_path, f"{folder_name}_v0_extract_text.json")
    output_json_path = os.path.join(folder_path, f"{folder_name}_v1_preprocessed_tool.json")
    print(f"Processing: {folder_name}")
    print(f"New JSON path: {new_json_path}")
    print(f"Output JSON path: {output_json_path}")

    if os.path.exists(output_json_path):
        print(f"Skipping {folder_name}, already processed.")
        return

    if os.path.exists(new_json_path):
        preprocess_text(new_json_path, output_json_path, tool)
        print(f"Processed: {folder_name}")

# %%
specific_path = os.path.abspath("/home/francia/research_hub/csr_project/CSR_report_processed_v4/NASDAQ/NASDAQ_AMD_2012_2013")
process_specific(specific_path, tool)
# Out:
# Processing: NASDAQ_AMD_2012_2013
# New JSON path: /home/francia/research_hub/csr_project/CSR_report_processed_v4/NASDAQ/NASDAQ_AMD_2012_2013/NASDAQ_AMD_2012_2013_v0_extract_text.json
# Output JSON path: /home/francia/research_hub/csr_project/CSR_report_processed_v4/NASDAQ/NASDAQ_AMD_2012_2013/NASDAQ_AMD_2012_2013_v1_preprocessed_tool.json
# Processed: NASDAQ_AMD_2012_2013
